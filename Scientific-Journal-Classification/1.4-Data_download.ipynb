# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Data scraping

# %% [markdown]
# # Imports

# %%
import os
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
from bs4 import BeautifulSoup
import os

import time
import random
from tqdm import tqdm

# %% [markdown]
# # Data download
# - [Setting up Beautiful soup for ACS: Analytical Chemistry Journal (low_HI)](Setting-up-Beautiful-soup-for-ACS:-Analytical-Chemistry-Journal-(low_HI)) - set up catalogue for downloading later.
# - [Setting up Beautiful soup for: Analytical and Bioanalytical Chemistry (high_HI)](Setting-up-Beautiful-soup-for-ACS:-Analytical-and-Bioanalytical-Chemistry-(high_HI)) - set up catalogue for downloading later.
# - [Set scraping function](Set-scraping-function) - to automate the webscraping process.
# - [Scrape & save](Scrape-&-save) - Export data for use in next section.

# %% [markdown]
# ## Setting up Beautiful soup for ACS: Analytical Chemistry Journal (low_HI)
# - Set up Beautiful soup
# - Pull and filter the initial catalogue of issues for low_HI journal.
# - Data starts from 2000 since the low_HI only has publications available starting from that year.
# - Export list for storage and use by `datagrab` function later

# %%
#set url, check reponse
low_url = "https://link.springer.com/journal/10809/volumes-and-issues"
low_res = requests.get(low_url)
low_res.status_code == 200
# Out:
# True

# %%
#create soup object with html parser
low_soup = BeautifulSoup(low_res.content, 'html.parser')

#lookthrough
low_soup.extract()
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="pc,mobile" name="applicable-device"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Journal of Analytical Chemistry | Volumes and issues</title>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/oscar-static/img/favicons/springer/apple-touch-icon-1ee298e6a2.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/oscar-static/img/favicons/springer/favicon-32x32-da5cbe81a8.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/oscar-static/img/favicons/springer/favicon-16x16-b154d15d9a.png" rel="icon" sizes="16x16" type="image/png"/>
# <link data-test="shortcut-icon" href="/oscar-static/img/favicons/springer/favicon-d1430c5053.ico" rel="shortcut icon"/>
# <link href="/oscar-static/app-springercom/manifest-31044b92ab.json" rel="manifest"/>
# <meta content="/oscar-static/app-springercom/browserconfig-9445b29a7c.xml" name="msapplication-config"/>
# <meta content="#e6e6e6" name="msapplication-TileColor"/>
# <meta content="/oscar-static/img/favicons/springer/app-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#e6e6e6" name="theme-color"/>
# <script>(function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement)</script>
# <link href="/oscar-static/app-springercom/css/core-b516af10bc.css" media="screen" rel="stylesheet"/>
# <link href="/oscar-static/app-springercom/css/print-b8af42253b.css" media="print" rel="stylesheet"/>
# <link data-test="enhanced-stylesheet" href="/oscar-static/app-springercom/css/enhanced-da2fea332b.css" media="only print, only all and (prefers-color-scheme: no-preference), only all and (prefers-color-scheme: light), only all and (prefers-color-scheme: dark)" rel="stylesheet"/>
# <script type="text/javascript">
#         config = {
#             env: 'live',
#             site: '10809.springer.com',
#             siteWithPath: '10809.springer.com' + window.location.pathname,
#             twitterHashtag: '10809',
#             cmsPrefix: 'https://studio-cms.springernature.com/studio/',
#
#
#
#
#             publisherBrand: 'Springer',
#             mustardcut: false
#         };
#     </script>
# <script data-test="dataLayer" type="text/javascript">
#         window.dataLayer = [{"Event Category":"Volumes and Issues page","GA Key":"UA-26408784-1","Journal Id":"10809","Journal Title":"Journal of Analytical Chemistry","page":{"category":{"pageType":"journalHome"},"attributes":{"featureFlags":[{"name":"ab_test_darwin_journal_page","active":false}],"environment":"live"},"name":"Journal other"},"japan":false}];
#     </script>
# <script>
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({
#                     ga4MeasurementId: 'G-B3E4QL2TPR',
#                     ga360TrackingId: 'UA-26408784-1',
#                     twitterId: 'o47a7',
#                     ga4ServerUrl: 'https://collect.springer.com',
#                     imprint: 'springer',
#                     page: {
#                         attributes: {
#                             featureFlags: [
#                             'darwin-universal-header'
#                             ]
#                         }
#                     }
#                 });
#             </script>
# <script>
#     (function(w, d) {
#         w.config = w.config || {};
#         w.config.mustardcut = false;
#
#
#         if (w.matchMedia && w.matchMedia('only print, only all and (prefers-color-scheme: no-preference), only all and (prefers-color-scheme: light), only all and (prefers-color-scheme: dark)').matches) {
#             w.config.mustardcut = true;
#             d.classList.add('js');
#             d.classList.remove('grade-c');
#             d.classList.remove('no-js');
#         }
#     })(window, document.documentElement);
# </script>
# <script>
#     (function () {
#         if ( typeof window.CustomEvent === "function" ) return false;
#         function CustomEvent ( event, params ) {
#             params = params || { bubbles: false, cancelable: false, detail: null };
#             var evt = document.createEvent( 'CustomEvent' );
#             evt.initCustomEvent( event, params.bubbles, params.cancelable, params.detail );
#             return evt;
#         }
#
#         CustomEvent.prototype = window.Event.prototype;
#
#         window.CustomEvent = CustomEvent;
#     })();
# </script>
# <script class="js-entry">
#     if (window.config.mustardcut) {
#         (function(w, d) {
#
#
#             var currentScript = d.currentScript || d.head.querySelector('script.js-entry');
#
#
#             function catchNoModuleSupport() {
#                 var scriptEl = d.createElement('script');
#                 return (!('noModule' in scriptEl) && 'onbeforeload' in scriptEl)
#             }
#
#             var headScripts = [
#                 {'src': '/oscar-static/js/polyfill-es5-bundle-51eb718839.js', 'async': false},
#                 {'src': '/oscar-static/js/airbrake-es5-bundle-cc5b57adf8.js', 'async': false},
#             ];
#
#             var bodyScripts = [
#
#                     {'src': '/oscar-static/js/app-es5-bundle-3a7b18cea2.js', 'async': false, 'module': false},
#                     {'src': '/oscar-static/js/app-es6-bundle-d751e653b1.js', 'async': false, 'module': true}
#
#
#
#             ];
#
#             function createScript(script) {
#                 var scriptEl = d.createElement('script');
#                 scriptEl.src = script.src;
#                 scriptEl.async = script.async;
#                 if (script.module === true) {
#                     scriptEl.type = "module";
#                     if (catchNoModuleSupport()) {
#                         scriptEl.src = '';
#                     }
#                 } else if (script.module === false) {
#                     scriptEl.setAttribute('nomodule', true)
#                 }
#                 if (script.charset) {
#                     scriptEl.setAttribute('charset', script.charset);
#                 }
#
#                 return scriptEl;
#             }
#
#             for (var i = 0; i < headScripts.length; ++i) {
#                 var scriptEl = createScript(headScripts[i]);
#                 currentScript.parentNode.insertBefore(scriptEl, currentScript.nextSibling);
#             }
#
#             d.addEventListener('DOMContentLoaded', function() {
#                 for (var i = 0; i < bodyScripts.length; ++i) {
#                     var scriptEl = createScript(bodyScripts[i]);
#                     d.body.appendChild(scriptEl);
#                 }
#             });
#
#             // Webfont repeat view
#             var config = w.config;
#             if (config && config.publisherBrand && sessionStorage.fontsLoaded === 'true') {
#                 d.documentElement.className += ' webfonts-loaded';
#             }
#         })(window, document);
#     }
# </script>
# <script data-test="gtm-head">
#     window.initGTM = function() {
#         if (window.config.mustardcut) {
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || [];
#                 w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#                 var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s),
#                         dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-MRVXSHQ');
#         }
#     }
# </script>
# <script>
# (function (w, d, t) {
#     function cc() {
#         var h = w.location.hostname;
#         var e = d.createElement(t),
#         s = d.getElementsByTagName(t)[0];
#
#
#         if (h.indexOf('springer.com') > -1 && h.indexOf('biomedcentral.com') === -1 && h.indexOf('springeropen.com') === -1) {
#             if (h.indexOf('link-qa.springer.com') > -1 || h.indexOf('test-www.springer.com') > -1) {
#                 e.src = 'https://cmp-static.springer.com/production_live/en/consent-bundle-17-36.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp-static.springer.com/production_live/en/consent-bundle-17-36.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('biomedcentral.com') > -1) {
#             if (h.indexOf('biomedcentral.com.qa') > -1) {
#                 e.src = 'https://cmp.biomedcentral.com/production_live/en/consent-bundle-15-23.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp.biomedcentral.com/production_live/en/consent-bundle-15-23.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('springeropen.com') > -1) {
#             if (h.indexOf('springeropen.com.qa') > -1) {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-16-25.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-16-25.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('springernature.com') > -1) {
#             if (h.indexOf('beta-qa.springernature.com') > -1) {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-49-27.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-NK22KLS')");
#             } else {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-49-27.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-NK22KLS')");
#             }
#         } else {
#             e.src = '/oscar-static/js/cookie-consent-es5-bundle-2b0f06c1e4.js';
#             e.setAttribute('data-consent', h);
#         }
#         s.insertAdjacentElement('afterend', e);
#     }
#
#     cc();
# })(window, document, 'script');
# </script>
# <link href="https://link.springer.com/journal/10809/volumes-and-issues" rel="canonical">
# <meta content="Journal of Analytical Chemistry, Analytical Chemistry" name="keywords">
# <meta content="Volumes and issues listings for Journal of Analytical Chemistry" name="description">
# <meta content="https://link.springer.com/journal/10809/volumes-and-issues" property="og:url">
# <meta content="website" property="og:type">
# <meta content="SpringerLink" property="og:site_name">
# <meta content="Journal of Analytical Chemistry | Volumes and issues" property="og:title">
# <meta content="Volumes and issues listings for Journal of Analytical Chemistry" property="og:description">
# <meta content="https://media.springernature.com/w92/springer-static/cover/journal/10809.jpg" property="og:image">
# <meta content="Journal of Analytical Chemistry | Volumes and issues" property="twitter:title">
# <meta content="Journal of Analytical Chemistry Cover Image" property="twitter:image:alt"/>
# <meta content="Volumes and issues listings for Journal of Analytical Chemistry" property="twitter:description"/>
# <meta content="https://media.springernature.com/w92/springer-static/cover/journal/10809.jpg" property="twitter:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></meta></link></head>
# <body class="journal" data-test="springer-journal-default-page">
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-
2H3.385l2.482-2.482a.994.994 0 00.02-1.403 1.001 1.001 0 00-1.417 0L.294 5.292a1.001 1.001 0 000 1.416l4.176 4.177a.991.991 0 001.4.016 1 1 0 00-.003-1.42L3.385 7H15z"></path></symbol><symbol id="icon-springer-arrow-right"><path d="M1 7a1 1 0 010-2h11.615l-2.482-2.482a.994.994 0 01-.02-1.403 1.001 1.001 0 011.417 0l4.176 4.177a1.001 1.001 0 010 1.416l-4.176 4.177a.991.991 0 01-1.4.016 1 1 0 01.003-1.42L12.615 7H1z"></path></symbol><symbol id="icon-springer-collections" viewbox="3 3 32 32"><path d="M25.583333,30.1249997 L25.583333,7.1207574 C25.583333,7.10772495 25.579812,7.10416665 25.5859851,7.10416665 L6.10400517,7.10571021 L6.10400517,30.1355179 C6.10400517,31.1064087 6.89406744,31.8958329 7.86448169,31.8958329 L26.057145,31.8958329 C25.7558021,31.374901 25.583333,30.7700915 25.583333,30.1249997 Z M4.33333333,30.1355179 L4.33333333,7.10571021 C4.33333333,6.12070047 5.12497502,5.33333333 6.10151452,5.33333333 L25.5859851,5.33333333 C26.5617372,5.33333333 27.3541664,6.13359035 27.3541664,7.1207574 L27.3541664,12.4166666 L32.6666663,12.4166666 L32.6666663,30.1098941 C32.6666663,32.0694626 31.0857174,33.6666663 29.1355179,33.6666663 L7.86448169,33.6666663 C5.91736809,33.6666663 4.33333333,32.0857174 4.33333333,30.1355179 Z M27.3541664,14.1874999 L27.3541664,30.1249997 C27.3541664,31.1030039 28.1469954,31.8958329 29.1249997,31 ...
# </div>
# <a class="c-skip-link" href="#main-content">Skip to main content</a>
# <div class="c-page-layout c-page-layout--sticky-footer">
# <div class="c-page-layout__header">
# <div class="app-elements u-mb-24">
# <header class="c-header" data-header="">
# <div class="c-header__container" data-header-expander-anchor="">
# <div class="c-header__brand">
# <a data-test="logo" data-track="click" data-track-action="click logo link" data-track-category="unified header" data-track-label="link" href="https://link.springer.com">
# <img alt="SpringerLink" src="/oscar-static/images/darwin/header/img/logo-springerlink-39ee2a28d8.svg"/>
# </a>
# </div>
# <a class="c-header__link c-header__link--static" data-track="click" data-track-action="click log in link" data-track-category="unified header" data-track-label="link" href="https://link.springer.com/signup-login?previousUrl=https%3A%2F%2Flink.springer.com%2Fjournal%2F10809%2Fvolumes-and-issues">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-user-single"></use>
# </svg><span>Log in</span>
# </a>
# </div>
# <nav aria-label="header navigation" class="c-header__nav">
# <div class="c-header__nav-container">
# <div class="c-header__item c-header__item--menu">
# <a class="c-header__link" data-header-expander="" href="#header-nav">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-menu"></use>
# </svg><span>Menu</span>
# </a>
# </div>
# <div class="c-header__item c-header__item--inline-links">
# <a class="c-header__link" data-track="click" data-track-action="click find a journal" data-track-label="link" href="https://link.springer.com/journals/a/1">Find a journal</a>
# <a class="c-header__link" data-track="click" data-track-action="click publish with us link" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish with us</a>
# </div>
# <div class="c-header__link-container">
# <div class="c-header__item c-header__item--divider">
# <a class="c-header__link" data-header-expander="" href="#popup-search">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-search"></use>
# </svg><span>Search</span>
# </a>
# </div>
# <div class="c-header__item">
# <div class="c-header__cart-icon">
# <div class="c-header__item ecommerce-cart" id="ecommerce-header-cart-icon-link" style="display:inline-block">
# <a class="c-header__link" href="https://order.springer.com/public/cart" style="appearance:none;border:none;background:none;color:inherit;position:relative">
# <svg aria-hidden="true" focusable="false" height="24" id="eds-i-cart" style="vertical-align:bottom" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M2 1a1 1 0 0 0 0 2l1.659.001 2.257 12.808a2.599 2.599 0 0 0 2.435 2.185l.167.004 9.976-.001a2.613 2.613 0 0 0 2.61-1.748l.03-.106 1.755-7.82.032-.107a2.546 2.546 0 0 0-.311-1.986l-.108-.157a2.604 2.604 0 0 0-2.197-1.076L6.042 5l-.56-3.17a1 1 0 0 0-.864-.82l-.12-.007L2.001 1ZM20.35 6.996a.63.63 0 0 1 .54.26.55.55 0 0 1 .082.505l-.028.1L19.2 15.63l-.022.05c-.094.177-.282.299-.526.317l-10.145.002a.61.61 0 0 1-.618-.515L6.394 6.999l13.955-.003ZM18 19a2 2 0 1 0 0 4 2 2 0 0 0 0-4ZM8 19a2 2 0 1 0 0 4 2 2 0 0 0 0-4Z" fill="currentColor" fill-rule="nonzero"></path>
# </svg><span style="padding-left:10px">Cart</span><span class="cart-info" style="display:none;position:absolute;top:10px;right:45px;background-color:#C65301;color:#fff;width:18px;height:18px;font-size:11px;border-radius:50%;line-height:17.5px;text-align:center"></span></a>
# <script>(function () { var exports = {}; if (window.fetch) {
#
#             "use strict";
# Object.defineProperty(exports, "__esModule", { value: true });
# exports.headerWidgetClientInit = void 0;
# var headerWidgetClientInit = function (getCartInfo) {
#     console.log("listen to updatedCart event");
#     document.body.addEventListener("updatedCart", function () {
#         console.log("updatedCart happened");
#         updateCartIcon().then(function () { return console.log("Cart state update upon event"); });
#     }, false);
#     return updateCartIcon().then(function () { return console.log("Initial cart state update"); });
#     function updateCartIcon() {
#         return getCartInfo()
#             .then(function (res) { return res.json(); })
#             .then(refreshCartState)
#             .catch(function () { return console.log("Could not fetch cart info"); });
#     }
#     function refreshCartState(json) {
#         var indicator = document.querySelector("#ecommerce-header-cart-icon-link .cart-info");
#         /* istanbul ignore else */
#         if (indicator && json.itemCount) {
#             indicator.style.display = 'block';
#             indicator.textContent = json.itemCount > 9 ? '9+' : json.itemCount.toString();
#             var moreThanOneItem = json.itemCount > 1;
#             indicator.setAttribute('title', "there ".concat(moreThanOneItem ? "are" : "is", " ").concat(json.itemCount, " item").concat(moreThanOneItem ? "s" : "", " in your cart"));
#         }
#         return json;
#     }
# };
# exports.headerWidgetClientInit = headerWidgetClientInit;
#
#
#             headerWidgetClientInit(
#               function () {
#                 return window.fetch("https://cart.springer.com/cart-info", {
#                   credentials: "include",
#                   headers: { Accept: "application/json" }
#                 })
#               }
#             )
#         }})()</script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </header>
# </div>
# <header class="u-mb-24" data-test="journal-header">
# <div class="u-container">
# <div class="c-product-header">
# <div class="c-product-header__theme" style="background-image: url('https://media.springernature.com/dominant-colour/springer-static/cover/journal/10809.jpg')"></div>
# <div class="c-product-header__content">
# <div class="c-product-header__main">
# <div class="c-product-header__cover">
# <img alt="" src="https://media.springernature.com/w92/springer-static/cover/journal/10809.jpg" srcset="
#                                         https://media.springernature.com/w92/springer-static/cover/journal/10809.jpg 1x,
#                                         https://media.springernature.com/w138/springer-static/cover/journal/10809.jpg 1.5x,
#                                         https://media.springernature.com/w184/springer-static/cover/journal/10809.jpg 2x,
#                                         https://media.springernature.com/w276/springer-static/cover/journal/10809.jpg 3x">
# </img></div>
# <div class="u-flex-shrink">
# <div class="c-product-header__title" id="journalTitle">
# <a data-track="click" data-track-action="click journal title" data-track-category="journal header" href="/journal/10809">Journal of Analytical Chemistry</a>
# </div>
# </div>
# </div>
# <div class="c-product-header__side"></div>
# </div>
# </div>
# </div>
# </header>
# <nav aria-label="breadcrumbs" class="u-container" data-test="article-breadcrumbs">
# <ol class="c-breadcrumbs c-breadcrumbs--truncated" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li class="c-breadcrumbs__item" id="breadcrumb0" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a class="c-breadcrumbs__link" data-test="journal-homepage-breadcrumb" data-track="click" data-track-action="breadcrumbs" data-track-category="journal" data-track-label="breadcrumb1" href="/journal/10809" itemprop="item"><span itemprop="name">Journal of Analytical Chemistry</span></a><meta content="1" itemprop="position"/>
# <svg aria-hidden="true" class="c-breadcrumbs__chevron" focusable="false" height="10" role="img" viewbox="0 0 10 10" width="10" xmlns="http://www.w3.org/2000/svg">
# <path d="m5.96738168 4.70639573 2.39518594-2.41447274c.37913917-.38219212.98637524-.38972225 1.35419292-.01894278.37750606.38054586.37784436.99719163-.00013556 1.37821513l-4.03074001 4.06319683c-.37758093.38062133-.98937525.38100976-1.367372-.00003075l-4.03091981-4.06337806c-.37759778-.38063832-.38381821-.99150444-.01600053-1.3622839.37750607-.38054587.98772445-.38240057 1.37006824.00302197l2.39538588 2.4146743.96295325.98624457z" fill="#666" fill-rule="evenodd" transform="matrix(0 -1 1 0 0 10)"></path>
# </svg>
# </li>
# <li class="c-breadcrumbs__item" id="breadcrumb1" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span data-test="page-title-breadcrumb" itemprop="name">Volumes and issues</span><meta content="2" itemprop="position"/>
# </li>
# </ol>
# </nav>
# </div>
# <div class="c-page-layout__body" id="main-content" role="main">
# <div class="u-container">
# <div class="l-with-sidebar u-mb-48">
# <div class="u-text-sans-serif">
# <div class="u-mb-24">
# <div class="app-search">
# <form action="/search" data-track="submit" data-track-action="user performed journal scope search on volumes and issues page" method="GET" role="search">
# <label class="app-search__label" for="search-within-journal">Search within journal</label>
# <div class="app-search__content">
# <input autocomplete="off" class="app-search__input" data-search-input="" id="search-within-journal" name="query" required="true" type="text" value=""/>
# <button class="app-search__button" type="submit">
# <span class="u-visually-hidden">Search</span>
# <svg aria-hidden="true" class="u-icon" focusable="false">
# <use xlink:href="#icon-search"></use>
# </svg>
# </button>
# <input data-test="journal-search" name="search-within" type="hidden" value="Journal"/>
# <input name="facet-journal-id" type="hidden" value="10809"/>
# </div>
# </form>
# </div>
# </div>
# <h1 data-test="page-title">Volumes and issues</h1>
# <script>
#         window.dataLayer.push({
#             imprint: 'springerlink'
#         });
#     </script>
# <ul class="u-list-reset" data-test="springer-volumes-and-issues">
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 78</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - August 2023</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-8">August 2023, issue 8</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-7">July 2023, issue 7</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-6">June 2023, issue 6</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-5">May 2023, issue 5</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-4">April 2023, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-3">March 2023, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-2">February 2023, issue 2</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/78-1">January 2023, issue 1</a></li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 77</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2022</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-14">December 2022, issue 14</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-13">December 2022, issue 13</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-12">December 2022, issue 12</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-11">November 2022, issue 11</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-10">October 2022, issue 10</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Special Issue: The issue is dedicated to the 90th anniversary of the Honorary Editor-in-Chief of the Journal of Analytical Chemistry Professor Yury A. Zolotov</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-9">September 2022, issue 9</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Special Issue: Development of Analytical Chemistry in Saratov. Compiling editor T.Yu. Rusanova</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-8">August 2022, issue 8</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-7">July 2022, issue 7</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-6">June 2022, issue 6</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-5">May 2022, issue 5</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-4">April 2022, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-3">March 2022, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-2">February 2022, issue 2</a>
# <p class="u-text-sm u-mb-0 u-mt-4">A part of the articles in this issue are related to  Chemosensors  special issue (quest editor: D.O. Kirsanov)</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/77-1">January 2022, issue 1</a></li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 76</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2021</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-14">December 2021, issue 14</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-13">December 2021, issue 13</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-12">December 2021, issue 12</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-11">November 2021, issue 11</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-10">October 2021, issue 10</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-9">September 2021, issue 9</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-8">August 2021, issue 8</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-7">July 2021, issue 7</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-6">June 2021, issue 6</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-5">May 2021, issue 5</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-4">April 2021, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-3">March 2021, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-2">February 2021, issue 2</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/76-1">January 2021, issue 1</a></li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 75</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2020</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-14">December 2020, issue 14</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-13">December 2020, issue 13</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-12">December 2020, issue 12</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-11">November 2020, issue 11</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-10">October 2020, issue 10</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-9">September 2020, issue 9</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-8">August 2020, issue 8</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-7">July 2020, issue 7</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-6">June 2020, issue 6</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-5">May 2020, issue 5</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-4">April 2020, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-3">March 2020, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-2">February 2020, issue 2</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/75-1">January 2020, issue 1</a></li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 74</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2019</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-14">December 2019, issue 14</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-13">December 2019, issue 13</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-12">December 2019, issue 12</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-11">November 2019, issue 11</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-10">October 2019, issue 10</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-9">September 2019, issue 9</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-2/supplement">September 2019, issue 2</a>
# <div class="c-status-message c-status-message--info u-mt-16 u-text-xs">
# <svg aria-hidden="true" class="c-status-message__icon" focusable="false" height="16" role="img" width="16">
# <use xlink:href="#icon-info"></use>
# </svg>
# <span>This is a supplement</span>
# </div>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-8">August 2019, issue 8</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-7">July 2019, issue 7</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-1/supplement">July 2019, issue 1</a>
# <div class="c-status-message c-status-message--info u-mt-16 u-text-xs">
# <svg aria-hidden="true" class="c-status-message__icon" focusable="false" height="16" role="img" width="16">
# <use xlink:href="#icon-info"></use>
# </svg>
# <span>This is a supplement</span>
# </div>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-6">June 2019, issue 6</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-5">May 2019, issue 5</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-4">April 2019, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-3">March 2019, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-2">February 2019, issue 2</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/74-1">January 2019, issue 1</a></li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 73</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2018</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/73-14">December 2018, issue 14</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/73-13">December 2018, issue 13</a></li>
# <li class="c-list-group__item">
# ...
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/55-4">April 2000, issue 4</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/55-3">March 2000, issue 3</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/55-2">February 2000, issue 2</a></li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/10809/volumes-and-issues/55-1">January 2000, issue 1</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="l-with-sidebar__sidebar">
# <div class="app-sidebar-boxes">
# <div class="u-mb-24">
# <div class="c-box c-box--shadowed u-mb-24" data-test="for-authors" data-track-component="for authors">
# <h2 class="c-box__heading">For authors</h2>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="submission-guidelines-link" data-track="click" data-track-action="click submission guidelines" data-track-external="" href="https://www.springer.com/journal/10809/submission-guidelines">Submission guidelines</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="author-services" data-track="click" data-track-action="click author services" data-track-external="" href="https://authorservices.springernature.com/go/sn/?utm_source=For+Authors&amp;utm_medium=Website_SpringerLink&amp;utm_campaign=Platform+Experimentation+2022&amp;utm_id=PE2022">Language editing services</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="ethicsAndDisclosureGuidelines" data-track="click" data-track-action="click ethics &amp; disclosures" href="https://www.springer.com/journal/10809/ethics-and-disclosures">Ethics &amp; disclosures</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-track="click" data-track-action="click contact the journal" data-track-category="for authors" href="https://www.springer.com/journal/10809/contact-the-journal">Contact the journal</a>
# </div>
# <a class="u-button u-button--full-width u-button--primary" data-test="submit-manuscript-button" data-track="click" data-track-action="manuscript submission" data-track-category="Journal" data-track-external="" data-track-label="Journal of Analytical Chemistry" href="https://publish.sciencejournals.ru/journal-detail/JAC?lang=en">Submit manuscript<svg aria-hidden="true" class="u-ml-8" focusable="false" height="16" width="15"><use xlink:href="#icon-submit-open"></use></svg></a>
# </div>
# <div class="app-checklist-banner" data-test="checklist">
# <div class="app-checklist-banner__icon-container">
# <svg aria-hidden="true" class="app-checklist-banner__paper-icon" focusable="false">
# <use xlink:href="#icon-checklist-banner"></use>
# </svg>
# </div>
# <div class="app-checklist-banner__body">
# <h3 class="app-checklist-banner__title">Working on a manuscript?</h3>
# <p class="app-checklist-banner__copy">Avoid the most common mistakes and prepare your manuscript for journal editors.</p>
# <a class="app-checklist-banner__link" data-track="click" data-track-action="click checklist banner" data-track-category="pre-submission-checklist" data-track-label="link" href="https://beta.springernature.com/pre-submission?journalId=10809">
# <span>Learn more</span>
# <svg aria-hidden="true" class="app-checklist-banner__arrow-icon" focusable="false">
# <use xlink:href="#icon-arrow-right"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="u-mb-24">
# <div class="c-box c-box--shadowed" data-test="springer-explore-section" data-track-component="explore">
# <h2 class="c-box__heading">Explore</h2>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="volumes-and-issues" data-track="click" data-track-action="click volumes and issues" href="https://link.springer.com/journal/10809/volumes-and-issues">Volumes and issues</a>
# </div>
# <a class="u-button u-button--full-width" data-test="alertLink" data-track="click" data-track-action="click sign up for alerts" data-track-category="explore" data-track-external="" href="https://www.springer.com/alerts-frontend/subscribe?journalNo=10809">Sign up for alerts</a>
# </div>
# </div>
# </div>
# <aside class="c-ad c-ad--300x250">
# <div class="c-ad__inner">
# <p class="c-ad__label">Advertisement</p>
# <div data-ad-type="MPU1" data-gpt="" data-gpt-sizes="300x250" data-gpt-targeting="pos=MPU1;" data-gpt-unitpath="/270604982/springerlink/10809" data-pa11y-ignore="" data-test="MPU1-ad" id="div-gpt-ad-MPU1">
# <noscript>
# <a href="//pubads.g.doubleclick.net/gampad/jump?iu=/270604982/springerlink/10809&amp;sz=300x250&amp;pos=MPU1&amp;">
# <img alt="Advertisement" data-test="gpt-advert-fallback-img" height="250" src="//pubads.g.doubleclick.net/gampad/ad?iu=/270604982/springerlink/10809&amp;sz=300x250&amp;pos=MPU1&amp;" width="300"/>
# </a>
# </noscript>
# </div>
# </div>
# </aside>
# </div>
# </div>
# </div>
# </div>
# <div class="app-elements">
# <div class="c-header__expander" id="popup-search">
# <h2 class="c-header__heading">Search</h2>
# <div class="u-container">
# <div class="c-header__search">
# <form action="//link.springer.com/search" data-track="submit" data-track-action="submit search form" data-track-category="unified header" data-track-label="form" method="GET" role="search">
# <label class="c-header__search-label" for="header-search">Search by keyword or author</label>
# <div class="c-header__search-container">
# <input autocomplete="off" class="c-header__search-input" id="header-search" name="query" required="" type="text" value=""/>
# <button class="c-header__search-button" type="submit">
# <svg aria-hidden="true" class="c-header__icon" focusable="false">
# <use xlink:href="#icon-eds-search"></use>
# </svg>
# <span class="u-visually-hidden">Search</span>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="c-header__expander c-header__expander--menu" id="header-nav">
# <h2 class="c-header__heading">Navigation</h2>
# <ul class="c-header__list">
# <li class="c-header__list-item"><a class="c-header__link" data-track="click" data-track-action="click find a journal" data-track-label="link" href="https://link.springer.com/journals/a/1">Find a journal</a></li>
# <li class="c-header__list-item"><a class="c-header__link" data-track="click" data-track-action="click publish with us link" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish with us</a></li>
# </ul>
# </div>
# <footer>
# <div class="c-footer" data-track-component="unified-footer">
# <div class="c-footer__container">
# <div class="c-footer__grid c-footer__group--separator">
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Discover content</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="journals a-z" data-track-label="link" href="https://link.springer.com/journals/a/1">Journals A-Z</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="books a-z" data-track-label="link" href="https://link.springer.com/books/a/1">Books A-Z</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Publish with us</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="publish your research" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish your research</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="open access publishing" data-track-label="link" href="https://www.springernature.com/gp/open-research/about/the-fundamentals-of-open-access-and-open-research">Open access publishing</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Products and services</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="our products" data-track-label="link" href="https://www.springernature.com/gp/products">Our products</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="librarians" data-track-label="link" href="https://www.springernature.com/gp/librarians">Librarians</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="societies" data-track-label="link" href="https://www.springernature.com/gp/societies">Societies</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="partners and advertisers" data-track-label="link" href="https://www.springernature.com/gp/partners">Partners and advertisers</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Our imprints</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Springer" data-track-label="link" href="https://www.springer.com/">Springer</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Nature Portfolio" data-track-label="link" href="https://www.nature.com/">Nature Portfolio</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="BMC" data-track-label="link" href="https://www.biomedcentral.com/">BMC</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Palgrave Macmillan" data-track-label="link" href="https://www.palgrave.com/">Palgrave Macmillan</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Apress" data-track-label="link" href="https://www.apress.com/">Apress</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="c-footer__container">
# <nav aria-label="footer navigation">
# <ul class="c-footer__links">
# <li class="c-footer__item">
# <button class="c-footer__link" data-cc-action="preferences" data-track="click" data-track-action="Manage cookies" data-track-label="link"><span class="c-footer__button-text">Your privacy choices/Manage cookies</span></button>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="california privacy statement" data-track-label="link" href="https://www.springernature.com/gp/legal/ccpa">Your US state privacy rights</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="accessibility statement" data-track-label="link" href="https://www.springernature.com/gp/info/accessibility">Accessibility statement</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="terms and conditions" data-track-label="link" href="https://link.springer.com/termsandconditions">Terms and conditions</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="privacy policy" data-track-label="link" href="https://link.springer.com/privacystatement">Privacy policy</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="help and support" data-track-label="link" href="https://support.springernature.com/en/support/home">Help and support</a>
# </li>
# </ul>
# </nav>
# <div class="c-footer__user">
# <p class="c-footer__user-info">
# <span data-test="footer-user-ip">14.100.50.169</span>
# </p>
# <p class="c-footer__user-info" data-test="footer-business-partners">Not affiliated</p>
# </div>
# <a class="c-footer__link" href="https://www.springernature.com/">
# <img alt="Springer Nature" height="20" loading="lazy" src="/oscar-static/images/darwin/footer/img/logo-springernature_white-64dbfad7d8.svg" width="200">
# </img></a>
# <p class="c-footer__legal" data-test="copyright">© 2023 Springer Nature</p>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <div aria-hidden="true" class="u-visually-hidden">
# <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><path d="M0 .74h56.72v55.24H0z" id="a"></path></defs><symbol id="icon-access" viewbox="0 0 18 18"><path d="m14 8c.5522847 0 1 .44771525 1 1v7h2.5c.2761424 0 .5.2238576.5.5v1.5h-18v-1.5c0-.2761424.22385763-.5.5-.5h2.5v-7c0-.55228475.44771525-1 1-1s1 .44771525 1 1v6.9996556h8v-6.9996556c0-.55228475.4477153-1 1-1zm-8 0 2 1v5l-2 1zm6 0v7l-2-1v-5zm-2.42653766-7.59857636 7.03554716 4.92488299c.4162533.29137735.5174853.86502537.226108 1.28127873-.1721584.24594054-.4534847.39241464-.7536934.39241464h-14.16284822c-.50810197 0-.92-.41189803-.92-.92 0-.30020869.1464741-.58153499.39241464-.75369337l7.03554714-4.92488299c.34432015-.2410241.80260453-.2410241 1.14692468 0zm-.57346234 2.03988748-3.65526982 2.55868888h7.31053962z" fill-rule="evenodd"></path></symbol><symbol id="icon-account" viewbox="0 0 18 18"><path d="m10.2379028 16.9048051c1.3083556-.2032362 2.5118471-.7235183 3.5294683-1.4798399-.8731327-2.5141501-2.0638925-3.935978-3.7673711-4.3188248v-1.27684611c1.1651924-.41183641 2-1.52307546 2-2.82929429 0-1.65685425-1.3431458-3-3-3-1.65685425 0-3 1.34314575-3 3 0 1.30621883.83480763 2.41745788 2 2.82929429v1.27684611c-1.70347856.3828468-2.89423845 1.8046747-3.76737114 4.3188248 1.01762123.7563216 2.22111275 1.2766037 3.52946833 1.4798399.40563808.0629726.81921174.0951949 1.23790281.0951949s.83226473-.0322223 1.2379028-.0951949zm4.
# 'February 2000, issue 2'

# %%
#find catalogue via <a> elements within the <ul> element with class="c-list-group"
low_a_elements = low_soup.select('ul.c-list-group a')

low_catalogue = []
# Loop through the <a> elements and extract the href and text data
for a in low_a_elements:
    if a.text.strip() == 'January 2000, issue 1':
        break
    else:
        catalogue_issue = {'text' : a.text.strip(),    #strip to remove whitespaces
                           'href': a['href'],
                           'url' : 'https://link.springer.com' + a['href']
                  }
        low_catalogue.append(catalogue_issue)

#data export
if not os.path.exists('data'):
    os.makedirs('data')
pd.DataFrame(low_catalogue).to_csv('data/low_catalogue.csv', index = False)

len(low_catalogue)
# Out:
# 311

# %% [markdown]
# ## Setting up Beautiful soup for: Analytical and Bioanalytical Chemistry (high_HI)
# - Set up Beautiful soup
# - Pull and filter the initial catalogue of issues for high_HI journal.
# - Data to be filtered starting from 2000 since the low_HI only has publications available starting from that year.
# - Export list for storage and use by `datagrab` function later

# %%
#set url, check reponse for valid site
high_url = "https://link.springer.com/journal/216/volumes-and-issues"
res = requests.get(high_url)
res.status_code == 200
# Out:
# True

# %%
#create soup object with html parser
high_soup = BeautifulSoup(res.content, 'html.parser')

#lookthrough
high_soup.extract()
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="pc,mobile" name="applicable-device"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Analytical and Bioanalytical Chemistry | Volumes and issues</title>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/oscar-static/img/favicons/springer/apple-touch-icon-1ee298e6a2.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/oscar-static/img/favicons/springer/favicon-32x32-da5cbe81a8.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/oscar-static/img/favicons/springer/favicon-16x16-b154d15d9a.png" rel="icon" sizes="16x16" type="image/png"/>
# <link data-test="shortcut-icon" href="/oscar-static/img/favicons/springer/favicon-d1430c5053.ico" rel="shortcut icon"/>
# <link href="/oscar-static/app-springercom/manifest-31044b92ab.json" rel="manifest"/>
# <meta content="/oscar-static/app-springercom/browserconfig-9445b29a7c.xml" name="msapplication-config"/>
# <meta content="#e6e6e6" name="msapplication-TileColor"/>
# <meta content="/oscar-static/img/favicons/springer/app-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#e6e6e6" name="theme-color"/>
# <script>(function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement)</script>
# <link href="/oscar-static/app-springercom/css/core-b516af10bc.css" media="screen" rel="stylesheet"/>
# <link href="/oscar-static/app-springercom/css/print-b8af42253b.css" media="print" rel="stylesheet"/>
# <link data-test="enhanced-stylesheet" href="/oscar-static/app-springercom/css/enhanced-da2fea332b.css" media="only print, only all and (prefers-color-scheme: no-preference), only all and (prefers-color-scheme: light), only all and (prefers-color-scheme: dark)" rel="stylesheet"/>
# <script type="text/javascript">
#         config = {
#             env: 'live',
#             site: '216.springer.com',
#             siteWithPath: '216.springer.com' + window.location.pathname,
#             twitterHashtag: '216',
#             cmsPrefix: 'https://studio-cms.springernature.com/studio/',
#
#
#
#
#             publisherBrand: 'Springer',
#             mustardcut: false
#         };
#     </script>
# <script data-test="dataLayer" type="text/javascript">
#         window.dataLayer = [{"Event Category":"Volumes and Issues page","GA Key":"UA-26408784-1","Journal Id":"216","Journal Title":"Analytical and Bioanalytical Chemistry","page":{"category":{"pageType":"journalHome"},"attributes":{"featureFlags":[{"name":"ab_test_darwin_journal_page","active":false}],"environment":"live"},"name":"Journal other"},"japan":false}];
#     </script>
# <script>
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({
#                     ga4MeasurementId: 'G-B3E4QL2TPR',
#                     ga360TrackingId: 'UA-26408784-1',
#                     twitterId: 'o47a7',
#                     ga4ServerUrl: 'https://collect.springer.com',
#                     imprint: 'springer',
#                     page: {
#                         attributes: {
#                             featureFlags: [
#                             'darwin-universal-header'
#                             ]
#                         }
#                     }
#                 });
#             </script>
# <script>
#     (function(w, d) {
#         w.config = w.config || {};
#         w.config.mustardcut = false;
#
#
#         if (w.matchMedia && w.matchMedia('only print, only all and (prefers-color-scheme: no-preference), only all and (prefers-color-scheme: light), only all and (prefers-color-scheme: dark)').matches) {
#             w.config.mustardcut = true;
#             d.classList.add('js');
#             d.classList.remove('grade-c');
#             d.classList.remove('no-js');
#         }
#     })(window, document.documentElement);
# </script>
# <script>
#     (function () {
#         if ( typeof window.CustomEvent === "function" ) return false;
#         function CustomEvent ( event, params ) {
#             params = params || { bubbles: false, cancelable: false, detail: null };
#             var evt = document.createEvent( 'CustomEvent' );
#             evt.initCustomEvent( event, params.bubbles, params.cancelable, params.detail );
#             return evt;
#         }
#
#         CustomEvent.prototype = window.Event.prototype;
#
#         window.CustomEvent = CustomEvent;
#     })();
# </script>
# <script class="js-entry">
#     if (window.config.mustardcut) {
#         (function(w, d) {
#
#
#             var currentScript = d.currentScript || d.head.querySelector('script.js-entry');
#
#
#             function catchNoModuleSupport() {
#                 var scriptEl = d.createElement('script');
#                 return (!('noModule' in scriptEl) && 'onbeforeload' in scriptEl)
#             }
#
#             var headScripts = [
#                 {'src': '/oscar-static/js/polyfill-es5-bundle-51eb718839.js', 'async': false},
#                 {'src': '/oscar-static/js/airbrake-es5-bundle-cc5b57adf8.js', 'async': false},
#             ];
#
#             var bodyScripts = [
#
#                     {'src': '/oscar-static/js/app-es5-bundle-3a7b18cea2.js', 'async': false, 'module': false},
#                     {'src': '/oscar-static/js/app-es6-bundle-d751e653b1.js', 'async': false, 'module': true}
#
#
#
#             ];
#
#             function createScript(script) {
#                 var scriptEl = d.createElement('script');
#                 scriptEl.src = script.src;
#                 scriptEl.async = script.async;
#                 if (script.module === true) {
#                     scriptEl.type = "module";
#                     if (catchNoModuleSupport()) {
#                         scriptEl.src = '';
#                     }
#                 } else if (script.module === false) {
#                     scriptEl.setAttribute('nomodule', true)
#                 }
#                 if (script.charset) {
#                     scriptEl.setAttribute('charset', script.charset);
#                 }
#
#                 return scriptEl;
#             }
#
#             for (var i = 0; i < headScripts.length; ++i) {
#                 var scriptEl = createScript(headScripts[i]);
#                 currentScript.parentNode.insertBefore(scriptEl, currentScript.nextSibling);
#             }
#
#             d.addEventListener('DOMContentLoaded', function() {
#                 for (var i = 0; i < bodyScripts.length; ++i) {
#                     var scriptEl = createScript(bodyScripts[i]);
#                     d.body.appendChild(scriptEl);
#                 }
#             });
#
#             // Webfont repeat view
#             var config = w.config;
#             if (config && config.publisherBrand && sessionStorage.fontsLoaded === 'true') {
#                 d.documentElement.className += ' webfonts-loaded';
#             }
#         })(window, document);
#     }
# </script>
# <script data-test="gtm-head">
#     window.initGTM = function() {
#         if (window.config.mustardcut) {
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || [];
#                 w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#                 var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s),
#                         dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-MRVXSHQ');
#         }
#     }
# </script>
# <script>
# (function (w, d, t) {
#     function cc() {
#         var h = w.location.hostname;
#         var e = d.createElement(t),
#         s = d.getElementsByTagName(t)[0];
#
#
#         if (h.indexOf('springer.com') > -1 && h.indexOf('biomedcentral.com') === -1 && h.indexOf('springeropen.com') === -1) {
#             if (h.indexOf('link-qa.springer.com') > -1 || h.indexOf('test-www.springer.com') > -1) {
#                 e.src = 'https://cmp-static.springer.com/production_live/en/consent-bundle-17-36.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp-static.springer.com/production_live/en/consent-bundle-17-36.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('biomedcentral.com') > -1) {
#             if (h.indexOf('biomedcentral.com.qa') > -1) {
#                 e.src = 'https://cmp.biomedcentral.com/production_live/en/consent-bundle-15-23.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp.biomedcentral.com/production_live/en/consent-bundle-15-23.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('springeropen.com') > -1) {
#             if (h.indexOf('springeropen.com.qa') > -1) {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-16-25.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             } else {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-16-25.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-MRVXSHQ')");
#             }
#         } else if (h.indexOf('springernature.com') > -1) {
#             if (h.indexOf('beta-qa.springernature.com') > -1) {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-49-27.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-NK22KLS')");
#             } else {
#                 e.src = 'https://cmp.springernature.com/production_live/en/consent-bundle-49-27.js';
#                 e.setAttribute('onload', "initGTM(window,document,'script','dataLayer','GTM-NK22KLS')");
#             }
#         } else {
#             e.src = '/oscar-static/js/cookie-consent-es5-bundle-2b0f06c1e4.js';
#             e.setAttribute('data-consent', h);
#         }
#         s.insertAdjacentElement('afterend', e);
#     }
#
#     cc();
# })(window, document, 'script');
# </script>
# <link href="https://link.springer.com/journal/216/volumes-and-issues" rel="canonical">
# <meta content="Analytical and Bioanalytical Chemistry, Analytical Chemistry, Biochemistry, general, Laboratory Medicine, Characterization and Evaluation of Materials, Food Science, Monitoring/Environmental Analysis" name="keywords">
# <meta content="Volumes and issues listings for Analytical and Bioanalytical Chemistry" name="description">
# <meta content="https://link.springer.com/journal/216/volumes-and-issues" property="og:url">
# <meta content="website" property="og:type">
# <meta content="SpringerLink" property="og:site_name">
# <meta content="Analytical and Bioanalytical Chemistry | Volumes and issues" property="og:title">
# <meta content="Volumes and issues listings for Analytical and Bioanalytical Chemistry" property="og:description">
# <meta content="https://media.springernature.com/w92/springer-static/cover/journal/216.jpg" property="og:image">
# <meta content="Analytical and Bioanalytical Chemistry | Volumes and issues" property="twitter:title">
# <meta content="Analytical and Bioanalytical Chemistry Cover Image" property="twitter:image:alt"/>
# <meta content="Volumes and issues listings for Analytical and Bioanalytical Chemistry" property="twitter:description"/>
# <meta content="https://media.springernature.com/w92/springer-static/cover/journal/216.jpg" property="twitter:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# </meta></meta></meta></meta></meta></meta></meta></meta
985602z" fill-rule="evenodd"></path></symbol><symbol id="icon-springer-arrow-left"><path d="M15 7a1 1 0 000-2H3.385l2.482-2.482a.994.994 0 00.02-1.403 1.001 1.001 0 00-1.417 0L.294 5.292a1.001 1.001 0 000 1.416l4.176 4.177a.991.991 0 001.4.016 1 1 0 00-.003-1.42L3.385 7H15z"></path></symbol><symbol id="icon-springer-arrow-right"><path d="M1 7a1 1 0 010-2h11.615l-2.482-2.482a.994.994 0 01-.02-1.403 1.001 1.001 0 011.417 0l4.176 4.177a1.001 1.001 0 010 1.416l-4.176 4.177a.991.991 0 01-1.4.016 1 1 0 01.003-1.42L12.615 7H1z"></path></symbol><symbol id="icon-springer-collections" viewbox="3 3 32 32"><path d="M25.583333,30.1249997 L25.583333,7.1207574 C25.583333,7.10772495 25.579812,7.10416665 25.5859851,7.10416665 L6.10400517,7.10571021 L6.10400517,30.1355179 C6.10400517,31.1064087 6.89406744,31.8958329 7.86448169,31.8958329 L26.057145,31.8958329 C25.7558021,31.374901 25.583333,30.7700915 25.583333,30.1249997 Z M4.33333333,30.1355179 L4.33333333,7.10571021 C4.33333333,6.12070047 5.12497502,5.33333333 6.10151452,5.33333333 L25.5859851,5.33333333 C26.5617372,5.33333333 27.3541664,6.13359035 27.3541664,7.1207574 L27.3541664,12.4166666 L32.6666663,12.4166666 L32.6666663,30.1098941 C32.6666663,32.0694626 31.0857174,33.6666663 29.1355179,33.6666663 L7.86448169,33.6666663 C5.91736809,33.6666663 4.33333333,32.0857174 4.33333333,30.1355179 Z M27.3541664,14.1874999 L27.3541664,30.1249997 C27.3541664,31.1030039 28.1469954,31.8958329 29.1249997,31 ...
# </div>
# <a class="c-skip-link" href="#main-content">Skip to main content</a>
# <div class="c-page-layout c-page-layout--sticky-footer">
# <div class="c-page-layout__header">
# <div class="app-elements u-mb-24">
# <header class="c-header" data-header="">
# <div class="c-header__container" data-header-expander-anchor="">
# <div class="c-header__brand">
# <a data-test="logo" data-track="click" data-track-action="click logo link" data-track-category="unified header" data-track-label="link" href="https://link.springer.com">
# <img alt="SpringerLink" src="/oscar-static/images/darwin/header/img/logo-springerlink-39ee2a28d8.svg"/>
# </a>
# </div>
# <a class="c-header__link c-header__link--static" data-track="click" data-track-action="click log in link" data-track-category="unified header" data-track-label="link" href="https://link.springer.com/signup-login?previousUrl=https%3A%2F%2Flink.springer.com%2Fjournal%2F216%2Fvolumes-and-issues">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-user-single"></use>
# </svg><span>Log in</span>
# </a>
# </div>
# <nav aria-label="header navigation" class="c-header__nav">
# <div class="c-header__nav-container">
# <div class="c-header__item c-header__item--menu">
# <a class="c-header__link" data-header-expander="" href="#header-nav">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-menu"></use>
# </svg><span>Menu</span>
# </a>
# </div>
# <div class="c-header__item c-header__item--inline-links">
# <a class="c-header__link" data-track="click" data-track-action="click find a journal" data-track-label="link" href="https://link.springer.com/journals/a/1">Find a journal</a>
# <a class="c-header__link" data-track="click" data-track-action="click publish with us link" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish with us</a>
# </div>
# <div class="c-header__link-container">
# <div class="c-header__item c-header__item--divider">
# <a class="c-header__link" data-header-expander="" href="#popup-search">
# <svg aria-hidden="true" class="c-header__icon" focusable="false" height="24" width="24">
# <use xlink:href="#icon-eds-search"></use>
# </svg><span>Search</span>
# </a>
# </div>
# <div class="c-header__item">
# <div class="c-header__cart-icon">
# <div class="c-header__item ecommerce-cart" id="ecommerce-header-cart-icon-link" style="display:inline-block">
# <a class="c-header__link" href="https://order.springer.com/public/cart" style="appearance:none;border:none;background:none;color:inherit;position:relative">
# <svg aria-hidden="true" focusable="false" height="24" id="eds-i-cart" style="vertical-align:bottom" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M2 1a1 1 0 0 0 0 2l1.659.001 2.257 12.808a2.599 2.599 0 0 0 2.435 2.185l.167.004 9.976-.001a2.613 2.613 0 0 0 2.61-1.748l.03-.106 1.755-7.82.032-.107a2.546 2.546 0 0 0-.311-1.986l-.108-.157a2.604 2.604 0 0 0-2.197-1.076L6.042 5l-.56-3.17a1 1 0 0 0-.864-.82l-.12-.007L2.001 1ZM20.35 6.996a.63.63 0 0 1 .54.26.55.55 0 0 1 .082.505l-.028.1L19.2 15.63l-.022.05c-.094.177-.282.299-.526.317l-10.145.002a.61.61 0 0 1-.618-.515L6.394 6.999l13.955-.003ZM18 19a2 2 0 1 0 0 4 2 2 0 0 0 0-4ZM8 19a2 2 0 1 0 0 4 2 2 0 0 0 0-4Z" fill="currentColor" fill-rule="nonzero"></path>
# </svg><span style="padding-left:10px">Cart</span><span class="cart-info" style="display:none;position:absolute;top:10px;right:45px;background-color:#C65301;color:#fff;width:18px;height:18px;font-size:11px;border-radius:50%;line-height:17.5px;text-align:center"></span></a>
# <script>(function () { var exports = {}; if (window.fetch) {
#
#             "use strict";
# Object.defineProperty(exports, "__esModule", { value: true });
# exports.headerWidgetClientInit = void 0;
# var headerWidgetClientInit = function (getCartInfo) {
#     console.log("listen to updatedCart event");
#     document.body.addEventListener("updatedCart", function () {
#         console.log("updatedCart happened");
#         updateCartIcon().then(function () { return console.log("Cart state update upon event"); });
#     }, false);
#     return updateCartIcon().then(function () { return console.log("Initial cart state update"); });
#     function updateCartIcon() {
#         return getCartInfo()
#             .then(function (res) { return res.json(); })
#             .then(refreshCartState)
#             .catch(function () { return console.log("Could not fetch cart info"); });
#     }
#     function refreshCartState(json) {
#         var indicator = document.querySelector("#ecommerce-header-cart-icon-link .cart-info");
#         /* istanbul ignore else */
#         if (indicator && json.itemCount) {
#             indicator.style.display = 'block';
#             indicator.textContent = json.itemCount > 9 ? '9+' : json.itemCount.toString();
#             var moreThanOneItem = json.itemCount > 1;
#             indicator.setAttribute('title', "there ".concat(moreThanOneItem ? "are" : "is", " ").concat(json.itemCount, " item").concat(moreThanOneItem ? "s" : "", " in your cart"));
#         }
#         return json;
#     }
# };
# exports.headerWidgetClientInit = headerWidgetClientInit;
#
#
#             headerWidgetClientInit(
#               function () {
#                 return window.fetch("https://cart.springer.com/cart-info", {
#                   credentials: "include",
#                   headers: { Accept: "application/json" }
#                 })
#               }
#             )
#         }})()</script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </header>
# </div>
# <header class="u-mb-24" data-test="journal-header">
# <div class="u-container">
# <div class="c-product-header">
# <div class="c-product-header__theme" style="background-image: url('https://media.springernature.com/dominant-colour/springer-static/cover/journal/216.jpg')"></div>
# <div class="c-product-header__content">
# <div class="c-product-header__main">
# <div class="c-product-header__cover">
# <img alt="" src="https://media.springernature.com/w92/springer-static/cover/journal/216.jpg" srcset="
#                                         https://media.springernature.com/w92/springer-static/cover/journal/216.jpg 1x,
#                                         https://media.springernature.com/w138/springer-static/cover/journal/216.jpg 1.5x,
#                                         https://media.springernature.com/w184/springer-static/cover/journal/216.jpg 2x,
#                                         https://media.springernature.com/w276/springer-static/cover/journal/216.jpg 3x">
# </img></div>
# <div class="u-flex-shrink">
# <div class="c-product-header__title" id="journalTitle">
# <a data-track="click" data-track-action="click journal title" data-track-category="journal header" href="/journal/216">Analytical and Bioanalytical Chemistry</a>
# </div>
# </div>
# </div>
# <div class="c-product-header__side"></div>
# </div>
# </div>
# </div>
# </header>
# <nav aria-label="breadcrumbs" class="u-container" data-test="article-breadcrumbs">
# <ol class="c-breadcrumbs c-breadcrumbs--truncated" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li class="c-breadcrumbs__item" id="breadcrumb0" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a class="c-breadcrumbs__link" data-test="journal-homepage-breadcrumb" data-track="click" data-track-action="breadcrumbs" data-track-category="journal" data-track-label="breadcrumb1" href="/journal/216" itemprop="item"><span itemprop="name">Analytical and Bioanalytical Chemistry</span></a><meta content="1" itemprop="position"/>
# <svg aria-hidden="true" class="c-breadcrumbs__chevron" focusable="false" height="10" role="img" viewbox="0 0 10 10" width="10" xmlns="http://www.w3.org/2000/svg">
# <path d="m5.96738168 4.70639573 2.39518594-2.41447274c.37913917-.38219212.98637524-.38972225 1.35419292-.01894278.37750606.38054586.37784436.99719163-.00013556 1.37821513l-4.03074001 4.06319683c-.37758093.38062133-.98937525.38100976-1.367372-.00003075l-4.03091981-4.06337806c-.37759778-.38063832-.38381821-.99150444-.01600053-1.3622839.37750607-.38054587.98772445-.38240057 1.37006824.00302197l2.39538588 2.4146743.96295325.98624457z" fill="#666" fill-rule="evenodd" transform="matrix(0 -1 1 0 0 10)"></path>
# </svg>
# </li>
# <li class="c-breadcrumbs__item" id="breadcrumb1" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span data-test="page-title-breadcrumb" itemprop="name">Volumes and issues</span><meta content="2" itemprop="position"/>
# </li>
# </ol>
# </nav>
# </div>
# <div class="c-page-layout__body" id="main-content" role="main">
# <div class="u-container">
# <div class="l-with-sidebar u-mb-48">
# <div class="u-text-sans-serif">
# <div class="u-mb-24">
# <div class="app-search">
# <form action="/search" data-track="submit" data-track-action="user performed journal scope search on volumes and issues page" method="GET" role="search">
# <label class="app-search__label" for="search-within-journal">Search within journal</label>
# <div class="app-search__content">
# <input autocomplete="off" class="app-search__input" data-search-input="" id="search-within-journal" name="query" required="true" type="text" value=""/>
# <button class="app-search__button" type="submit">
# <span class="u-visually-hidden">Search</span>
# <svg aria-hidden="true" class="u-icon" focusable="false">
# <use xlink:href="#icon-search"></use>
# </svg>
# </button>
# <input data-test="journal-search" name="search-within" type="hidden" value="Journal"/>
# <input name="facet-journal-id" type="hidden" value="216"/>
# </div>
# </form>
# </div>
# </div>
# <h1 data-test="page-title">Volumes and issues</h1>
# <script>
#         window.dataLayer.push({
#             imprint: 'springerlink'
#         });
#     </script>
# <ul class="u-list-reset" data-test="springer-volumes-and-issues">
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 415</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - September 2023</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-21">September 2023, issue 21</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Recent Trends in (Bio)Analytical Chemistry/Guest Editors: Antje J. Baeumner ∙ Günter Gauglitz</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-20">August 2023, issue 20</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Teaching chromatography with systemic cause-effect relation maps/Enzyme-targeted NIR fluorescent probe for pesticides residues detection/Comparing LC-MS platforms for the analysis of zeranols in urine/Eco-compatible UV–Vis spectrophotometric method for  determining Cu2+</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-19">August 2023, issue 19</a>
# <p class="u-text-sm u-mb-0 u-mt-4">BLOCKR-dUThio-based method for detecting methyl transferase activity/Object-based image analysis tool for MS imaging ion classification/Chemical visualization of methamphetamine within fingerprints/Sample preparation of free sterols from vegetable oils by CCC</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-18">July 2023, issue 18</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Young Investigators in (Bio-)Analytical Chemistry 2023/Guest Editors: Zhi-Yuan Gu ∙ Beatriz Jurado-Sánchez ∙ Thomas H. Linz ∙ Leandro Wang Hantao ∙ Nongnoot Wongkaew ∙ Peng Wu</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-17">July 2023, issue 17</a>
# <p class="u-text-sm u-mb-0 u-mt-4">“Buddy check” peer observation activity for hands-on learning/Hidden threat in extensive hand hygiene during the Covid-19 pandemic/Detecting cancers via label-free SERS and deep learning/Label-free analysing biofilm phenotypes by IR micro- and correlation spectroscopy</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-16">July 2023, issue 16</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Best measurement challenge/On the way to SI traceable primary transfer standards/Hybrid biomaterials to preconcentrate toxic metals and metalloids/Revealing lipase-catalysed changes in essential oils by GC×GC‒MS</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-15">June 2023, issue 15</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Advances in Chemical Analysis of Micro- and Nanoplastics/Guest Editors: Natalia P. Ivleva ∙ Jennifer M. Lynch ∙ Sebastian Primpke</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-14">June 2023, issue 14</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Quantitative colorimetric sensing of heavy metal ions/Hyphenating dispersive liquid–liquid microextraction and solid-phase evaporation/XAI-enabled neural network analysis of metabolite spatial distributions/Detecting KRAS mutations in clinical samples</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-13">May 2023, issue 13</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Comprehensive 2D Chromatography/Guest Editors: Peter Q. Tranchida ∙ Luigi Mondello</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-12">May 2023, issue 12</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Research and education in analytical chemistry in Sweden/Caprylate esterase–activated fluorescent probes/Multiplex detection of clinical pathogen nucleic acids/Molecular ion formation on activated field emitters</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-11">May 2023, issue 11</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Analytical Nanoscience and Nanotechnology - In honor of Prof. Miguel Valcárcel/Guest Editors: Ángel Ríos ∙ Wolfgang J. Parak</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-10">April 2023, issue 10</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Meet the three newest ABC Editors/Rapid detection of three mycotoxins in animal feed materials/Competitive ELISA based on pH-responsive persistent luminescence nanoparticles/Carbon dots as a versatile tool to monitor insulin aggregation</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-9">April 2023, issue 9</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Wing-giving challenge/Flexible organic field-effect transistors-based biosensors/Efficient and low-cost nanoenzyme for decolorization of organic pollutants/Multi-element imaging of urinary stones by LA-ICP-MS</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-8">March 2023, issue 8</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Prediction of sensory attributes in winemaking grapes/Untargeted and targeted proteomics for secretome analysis of L-WRN cells/Combining microdialysis with UHPLC-QTOF/MS to screen for endogenous metabolites/SARS-CoV-2: Liposome-based high-throughput and point-of-care assays</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-7">March 2023, issue 7</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Advances in Extracellular Vesicle Analysis/Guest Editors: Lucile Alexandre ∙ Jiashu Sun ∙ Myriam Taverna ∙ Wenwan Zhong</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-6">March 2023, issue 6</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Electrochemical Biosensors – Driving Personalized Medicine/Guest Editors: Susana Campuzano ∙ María Jesús Lobo-Castañón</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-5">February 2023, issue 5</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Ion mobility electron capture dissociation mass spectrometry/3D imaging of ciprofloxacin in native-state biofilms with cryo-ToF–SIMS/Monitoring ultra- and diafiltration processes by Kalman-filtered Raman measurements/Robust and high-throughput lipidomic quantitation of human blood samples</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-4">February 2023, issue 4</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Improving droplet microfluidic systems for studying single bacteria growth/Rapid and sustainable HPLC method for the determination of uremic toxins/Negative photochromic spiropyran-containing fluorescent polymeric nanoprobe/Highly sensitive and quick in ovo sexing of domestic chicken eggs</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-3">January 2023, issue 3</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Graphene-on-gold SPR sensors resilient to high-temperature annealing/High-field asymmetric waveform IMS for glycoproteomic workflows/Automated detection of neutralizing SARS-CoV-2 antibodies in minutes/Ultrasensitive electrochemical immunosensor for carcinoembryonic antigen detection</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-2">January 2023, issue 2</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Modified TiO2 nanoparticles with potential-resolved multicolor ECL property/Insight into the role of pivotal ions in cellular regulatory volume decrease/Enriched stable 204Pb as tracer at ultra-low levels in clinical investigations/Targeted metabolite quantification by serial injection into isocratic gradients</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/415-1">January 2023, issue 1</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Maria Cruz Moreno Bondi—in memoriam/Symmetrical molecule NMR challenge/Imaging strategies for receptor tyrosine kinase dimers/Finding the tiny plastic needle in the haystack</p>
# </li>
# </ul>
# </li>
# <li class="app-section">
# <h2 class="app-section__heading app-section__heading--space-between-at-sm">
# <span class="u-display-block u-flex-grow">Volume 414</span>
# <span class="u-display-block u-flex-shrink u-text-sm u-text-sans-serif">January - December 2022</span>
# </h2>
# <ul class="c-list-group c-list-group--bordered c-list-group--flush c-list-group--sm u-mb-16">
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-29">December 2022, issue 29-30</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Thanks to reviewers in 2022/European analytical column number 50/Determining ginsenosides in Panax ginseng reference materials/E. coli biosensor for sensitive detection of lysine</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-28">November 2022, issue 28</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Diversity, equity, inclusion, and respect in analytical chemistry classrooms/Improving sensitivity and detection of LFAs for malaria biomarkers/COVID‑19 variants’ cross‑reactivity on particle counting immunoassays/Real-time monitoring of 5-HT release from living cells</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-27">November 2022, issue 27</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Accuracy of Raman spectroscopy in diagnosis of breast cancer/Portable electrochemiluminescence aptasensor for β-lactoglobulin detection/Efficiently separating phosphopeptides and phosphorylated exosomes/Characterization of vanillin carbon isotope delta reference materials</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-26">November 2022, issue 26</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Triple immunochromatographic test system to detect aquatic toxins/Analysing neuroprotective activity of selenium nanoparticles/Pump-free microfluidic chip for SERS detection of cancer biomarkers/Facile sulfur-quantum-dot-based photoluminescent probe</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-25">October 2022, issue 25</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Making Waves in Analytical Chemistry</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-24">October 2022, issue 24</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Maigret’s zinc phosphide challenge/Solid-phase microextraction: a fit-for-purpose technique in biomedical analysis/What if using certified reference materials was a requirement for publication?/Site-specific carbon isotope measurements of vanillin reference materials</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-23">September 2022, issue 23</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Teaching with simulation tools to introduce analytical chemistry instrumentation/Analysing double-emulsion droplets with ESI mass spectrometry/Spatial quantitation of antibiotics in bone tissue compartments/Micro-FTIR spectroscopy for detecting Citrus Huanglongbing</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-22">September 2022, issue 22</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Isothermal circular strand displacement–based assay for microRNA detection/Determination of short-chain fatty acids and their implication in influenza virus infection/Improved profiling of low molecular weight serum proteome/Electrochemical microfluidic multiplexed biosensors for on-site applications</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-21">September 2022, issue 21</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Sustainability in (Bio-)Analytical Chemistry</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-20">August 2022, issue 20</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Honoring Professor Günter Gauglitz/Surface-enhanced Raman spectroscopy for drug discovery/Peak broadening caused by micro–liquid chromatography detectors/Colorimetric sensor array for monitoring of meat freshness</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-19">August 2022, issue 19</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Point-of-care COVID-19 testing by colorimetric diagnosis/Structural elucidation of lignin degradation products/Coding recognition of dose–effect interdependence/Monitoring ibuprofen and its main metabolites in mussels</p>
# </li>
# <li class="c-list-group__item">
# <a class="u-interface-link u-text-sans-serif u-text-sm" href="/journal/216/volumes-and-issues/414-18">July 2022, issue 18</a>
# <p class="u-text-sm u-mb-0 u-mt-4">Promising Early-Career (Bio)Analytical Researchers</p>
# </li>
# <li class="c-list-group__item">
# ...
# <h2 class="c-box__heading">For authors</h2>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="submission-guidelines-link" data-track="click" data-track-action="click submission guidelines" data-track-external="" href="https://www.springer.com/journal/216/submission-guidelines">Submission guidelines</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="author-services" data-track="click" data-track-action="click author services" data-track-external="" href="https://authorservices.springernature.com/go/sn/?utm_source=For+Authors&amp;utm_medium=Website_SpringerLink&amp;utm_campaign=Platform+Experimentation+2022&amp;utm_id=PE2022">Language editing services</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="ethicsAndDisclosureGuidelines" data-track="click" data-track-action="click ethics &amp; disclosures" href="https://www.springer.com/journal/216/ethics-and-disclosures">Ethics &amp; disclosures</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="feesAndFunding" data-track="click" data-track-action="click fees and funding" href="https://www.springer.com/journal/216/how-to-publish-with-us#Fees%20and%20Funding">Open Access fees and funding</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-track="click" data-track-action="click contact the journal" data-track-category="for authors" href="https://www.springer.com/journal/216/contact-the-journal">Contact the journal</a>
# </div>
# <a class="u-button u-button--full-width u-button--primary" data-test="submit-manuscript-button" data-track="click" data-track-action="manuscript submission" data-track-category="Journal" data-track-external="" data-track-label="Analytical and Bioanalytical Chemistry" href="https://mc.manuscriptcentral.com/abc">Submit manuscript<svg aria-hidden="true" class="u-ml-8" focusable="false" height="16" width="15"><use xlink:href="#icon-submit-open"></use></svg></a>
# </div>
# <div class="app-checklist-banner" data-test="checklist">
# <div class="app-checklist-banner__icon-container">
# <svg aria-hidden="true" class="app-checklist-banner__paper-icon" focusable="false">
# <use xlink:href="#icon-checklist-banner"></use>
# </svg>
# </div>
# <div class="app-checklist-banner__body">
# <h3 class="app-checklist-banner__title">Working on a manuscript?</h3>
# <p class="app-checklist-banner__copy">Avoid the most common mistakes and prepare your manuscript for journal editors.</p>
# <a class="app-checklist-banner__link" data-track="click" data-track-action="click checklist banner" data-track-category="pre-submission-checklist" data-track-label="link" href="https://beta.springernature.com/pre-submission?journalId=216">
# <span>Learn more</span>
# <svg aria-hidden="true" class="app-checklist-banner__arrow-icon" focusable="false">
# <use xlink:href="#icon-arrow-right"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="u-mb-24">
# <div class="c-box c-box--shadowed" data-test="springer-explore-section" data-track-component="explore">
# <h2 class="c-box__heading">Explore</h2>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="online-first-articles" data-track="click" data-track-action="click online first articles" href="https://link.springer.com/journal/216/online-first">Online first articles</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="volumes-and-issues" data-track="click" data-track-action="click volumes and issues" href="https://link.springer.com/journal/216/volumes-and-issues">Volumes and issues</a>
# </div>
# <div class="u-text-sm u-mb-16">
# <a class="u-unvisited u-text-interface" data-test="collections" data-track="click" data-track-action="click collections" href="https://link.springer.com/journal/volumesAndIssues/216?tabName=topicalCollections">Collections</a>
# </div>
# <a class="u-button u-button--full-width" data-test="alertLink" data-track="click" data-track-action="click sign up for alerts" data-track-category="explore" data-track-external="" href="https://www.springer.com/alerts-frontend/subscribe?journalNo=216">Sign up for alerts</a>
# </div>
# </div>
# </div>
# <aside class="c-ad c-ad--300x250">
# <div class="c-ad__inner">
# <p class="c-ad__label">Advertisement</p>
# <div data-ad-type="MPU1" data-gpt="" data-gpt-sizes="300x250" data-gpt-targeting="pos=MPU1;" data-gpt-unitpath="/270604982/springerlink/216" data-pa11y-ignore="" data-test="MPU1-ad" id="div-gpt-ad-MPU1">
# <noscript>
# <a href="//pubads.g.doubleclick.net/gampad/jump?iu=/270604982/springerlink/216&amp;sz=300x250&amp;pos=MPU1&amp;">
# <img alt="Advertisement" data-test="gpt-advert-fallback-img" height="250" src="//pubads.g.doubleclick.net/gampad/ad?iu=/270604982/springerlink/216&amp;sz=300x250&amp;pos=MPU1&amp;" width="300"/>
# </a>
# </noscript>
# </div>
# </div>
# </aside>
# </div>
# </div>
# </div>
# </div>
# <div class="app-elements">
# <div class="c-header__expander" id="popup-search">
# <h2 class="c-header__heading">Search</h2>
# <div class="u-container">
# <div class="c-header__search">
# <form action="//link.springer.com/search" data-track="submit" data-track-action="submit search form" data-track-category="unified header" data-track-label="form" method="GET" role="search">
# <label class="c-header__search-label" for="header-search">Search by keyword or author</label>
# <div class="c-header__search-container">
# <input autocomplete="off" class="c-header__search-input" id="header-search" name="query" required="" type="text" value=""/>
# <button class="c-header__search-button" type="submit">
# <svg aria-hidden="true" class="c-header__icon" focusable="false">
# <use xlink:href="#icon-eds-search"></use>
# </svg>
# <span class="u-visually-hidden">Search</span>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="c-header__expander c-header__expander--menu" id="header-nav">
# <h2 class="c-header__heading">Navigation</h2>
# <ul class="c-header__list">
# <li class="c-header__list-item"><a class="c-header__link" data-track="click" data-track-action="click find a journal" data-track-label="link" href="https://link.springer.com/journals/a/1">Find a journal</a></li>
# <li class="c-header__list-item"><a class="c-header__link" data-track="click" data-track-action="click publish with us link" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish with us</a></li>
# </ul>
# </div>
# <footer>
# <div class="c-footer" data-track-component="unified-footer">
# <div class="c-footer__container">
# <div class="c-footer__grid c-footer__group--separator">
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Discover content</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="journals a-z" data-track-label="link" href="https://link.springer.com/journals/a/1">Journals A-Z</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="books a-z" data-track-label="link" href="https://link.springer.com/books/a/1">Books A-Z</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Publish with us</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="publish your research" data-track-label="link" href="https://www.springernature.com/gp/authors">Publish your research</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="open access publishing" data-track-label="link" href="https://www.springernature.com/gp/open-research/about/the-fundamentals-of-open-access-and-open-research">Open access publishing</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Products and services</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="our products" data-track-label="link" href="https://www.springernature.com/gp/products">Our products</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="librarians" data-track-label="link" href="https://www.springernature.com/gp/librarians">Librarians</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="societies" data-track-label="link" href="https://www.springernature.com/gp/societies">Societies</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="partners and advertisers" data-track-label="link" href="https://www.springernature.com/gp/partners">Partners and advertisers</a></li>
# </ul>
# </div>
# <div class="c-footer__group">
# <h3 class="c-footer__heading">Our imprints</h3>
# <ul class="c-footer__list">
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Springer" data-track-label="link" href="https://www.springer.com/">Springer</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Nature Portfolio" data-track-label="link" href="https://www.nature.com/">Nature Portfolio</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="BMC" data-track-label="link" href="https://www.biomedcentral.com/">BMC</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Palgrave Macmillan" data-track-label="link" href="https://www.palgrave.com/">Palgrave Macmillan</a></li>
# <li class="c-footer__item"><a class="c-footer__link" data-track="click" data-track-action="Apress" data-track-label="link" href="https://www.apress.com/">Apress</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="c-footer__container">
# <nav aria-label="footer navigation">
# <ul class="c-footer__links">
# <li class="c-footer__item">
# <button class="c-footer__link" data-cc-action="preferences" data-track="click" data-track-action="Manage cookies" data-track-label="link"><span class="c-footer__button-text">Your privacy choices/Manage cookies</span></button>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="california privacy statement" data-track-label="link" href="https://www.springernature.com/gp/legal/ccpa">Your US state privacy rights</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="accessibility statement" data-track-label="link" href="https://www.springernature.com/gp/info/accessibility">Accessibility statement</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="terms and conditions" data-track-label="link" href="https://link.springer.com/termsandconditions">Terms and conditions</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="privacy policy" data-track-label="link" href="https://link.springer.com/privacystatement">Privacy policy</a>
# </li>
# <li class="c-footer__item">
# <a class="c-footer__link" data-track="click" data-track-action="help and support" data-track-label="link" href="https://support.springernature.com/en/support/home">Help and support</a>
# </li>
# </ul>
# </nav>
# <div class="c-footer__user">
# <p class="c-footer__user-info">
# <span data-test="footer-user-ip">14.100.50.169</span>
# </p>
# <p class="c-footer__user-info" data-test="footer-business-partners">Not affiliated</p>
# </div>
# <a class="c-footer__link" href="https://www.springernature.com/">
# <img alt="Springer Nature" height="20" loading="lazy" src="/oscar-static/images/darwin/footer/img/logo-springernature_white-64dbfad7d8.svg" width="200">
# </img></a>
# <p class="c-footer__legal" data-test="copyright">© 2023 Springer Nature</p>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <div aria-hidden="true" class="u-visually-hidden">
# <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><path d="M0 .74h56.72v55.24H0z" id="a"></path></defs><symbol id="icon-access" viewbox="0 0 18 18"><path d="m14 8c.5522847 0 1 .44771525 1 1v7h2.5c.2761424 0 .5.2238576.5.5v1.5h-18v-1.5c0-.2761424.22385763-.5.5-.5h2.5v-7c0-.55228475.44771525-1 1-1s1 .44771525 1 1v6.9996556h8v-6.9996556c0-.55228475.4477153-1 1-1zm-8 0 2 1v5l-2 1zm6 0v7l-2-1v-5zm-2.42653766-7.59857636 7.03554716 4.92488299c.4162533.29137735.5174853.86502537.226108 1.28127873-.1721584.24594054-.4534847.39241464-.7536934.39241464h-14.16284822c-.50810197 0-.92-.41189803-.92-.92 0-.30020869.1464741-.58153499.39241464-.75369337l7.03554714-4.92488299c.34432015-.2410241.80260453-.2410241 1.14692468 0zm-.57346234 2.03988748-3.65526982 2.55868888h7.31053962z" fill-rule="evenodd"></path></symbol><symbol id="icon-account" viewbox="0 0 18 18"><path d="m10.2379028 16.9048051c1.3083556-.2032362 2.5118471-.7235183 3.5294683-1.4798399-.8731327-2.5141501-2.0638925-3.935978-3.7673711-4.3188248v-1.27684611c1.1651924-.41183641 2-1.52307546 2-2.82929429 0-1.65685425-1.3431458-3-3-3-1.65685425 0-3 1.34314575-3 3 0 1.30621883.83480763 2.41745788 2 2.82929429v1.27684611c-1.70347856.3828468-2.89423845 1.8046747-3.76737114 4.3188248 1.01762123.7563216 2.22111275 1.2766037 3.52946833 1.4798399.40563808.0629726.81921174.0951949 1.23790281.0951949s.83226473-.0322223 1.2379028-.0951949zm4.3421782-2.1721994c1.4927655-1.
#find catalogue via <a> elements within the <ul> element with class="c-list-group"
high_a_elements = high_soup.select('ul.c-list-group a')

high_catalogue = []
# Loop through the <a> elements and extract the href and text data
for a in high_a_elements:
    if a.text.strip() == 'January 2000, issue 1':      #set date
        break
    else:
        catalogue_issue = {'text' : a.text.strip(),    #strip to remove whitespaces
                           'href': a['href'],          #retain just incase.
                           'url' : 'https://link.springer.com' + a['href'] #form url
                  }
        high_catalogue.append(catalogue_issue)

#data export
if not os.path.exists('data'):
    os.makedirs('data')
pd.DataFrame(high_catalogue).to_csv('data/high_catalogue.csv', index = False)

len(high_catalogue)
# Out:
# 616

# %% [markdown]
# ## Set scraping function
# - Test and refine manual call of data
# - combinne into a function

# %%
#import back in catalogue
low_catalogue_df = pd.read_csv('data/low_catalogue.csv')
low_catalogue = low_catalogue_df.to_dict('records')

# %%
low_catalogue
# Out:
# [{'text': 'August 2023, issue 8',
#   'href': '/journal/10809/volumes-and-issues/78-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-8'},
#  {'text': 'July 2023, issue 7',
#   'href': '/journal/10809/volumes-and-issues/78-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-7'},
#  {'text': 'June 2023, issue 6',
#   'href': '/journal/10809/volumes-and-issues/78-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-6'},
#  {'text': 'May 2023, issue 5',
#   'href': '/journal/10809/volumes-and-issues/78-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-5'},
#  {'text': 'April 2023, issue 4',
#   'href': '/journal/10809/volumes-and-issues/78-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-4'},
#  {'text': 'March 2023, issue 3',
#   'href': '/journal/10809/volumes-and-issues/78-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-3'},
#  {'text': 'February 2023, issue 2',
#   'href': '/journal/10809/volumes-and-issues/78-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-2'},
#  {'text': 'January 2023, issue 1',
#   'href': '/journal/10809/volumes-and-issues/78-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/78-1'},
#  {'text': 'December 2022, issue 14',
#   'href': '/journal/10809/volumes-and-issues/77-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-14'},
#  {'text': 'December 2022, issue 13',
#   'href': '/journal/10809/volumes-and-issues/77-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-13'},
#  {'text': 'December 2022, issue 12',
#   'href': '/journal/10809/volumes-and-issues/77-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-12'},
#  {'text': 'November 2022, issue 11',
#   'href': '/journal/10809/volumes-and-issues/77-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-11'},
#  {'text': 'October 2022, issue 10',
#   'href': '/journal/10809/volumes-and-issues/77-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-10'},
#  {'text': 'September 2022, issue 9',
#   'href': '/journal/10809/volumes-and-issues/77-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-9'},
#  {'text': 'August 2022, issue 8',
#   'href': '/journal/10809/volumes-and-issues/77-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-8'},
#  {'text': 'July 2022, issue 7',
#   'href': '/journal/10809/volumes-and-issues/77-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-7'},
#  {'text': 'June 2022, issue 6',
#   'href': '/journal/10809/volumes-and-issues/77-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-6'},
#  {'text': 'May 2022, issue 5',
#   'href': '/journal/10809/volumes-and-issues/77-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-5'},
#  {'text': 'April 2022, issue 4',
#   'href': '/journal/10809/volumes-and-issues/77-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-4'},
#  {'text': 'March 2022, issue 3',
#   'href': '/journal/10809/volumes-and-issues/77-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-3'},
#  {'text': 'February 2022, issue 2',
#   'href': '/journal/10809/volumes-and-issues/77-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-2'},
#  {'text': 'January 2022, issue 1',
#   'href': '/journal/10809/volumes-and-issues/77-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/77-1'},
#  {'text': 'December 2021, issue 14',
#   'href': '/journal/10809/volumes-and-issues/76-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-14'},
#  {'text': 'December 2021, issue 13',
#   'href': '/journal/10809/volumes-and-issues/76-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-13'},
#  {'text': 'December 2021, issue 12',
#   'href': '/journal/10809/volumes-and-issues/76-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-12'},
#  {'text': 'November 2021, issue 11',
#   'href': '/journal/10809/volumes-and-issues/76-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-11'},
#  {'text': 'October 2021, issue 10',
#   'href': '/journal/10809/volumes-and-issues/76-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-10'},
#  {'text': 'September 2021, issue 9',
#   'href': '/journal/10809/volumes-and-issues/76-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-9'},
#  {'text': 'August 2021, issue 8',
#   'href': '/journal/10809/volumes-and-issues/76-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-8'},
#  {'text': 'July 2021, issue 7',
#   'href': '/journal/10809/volumes-and-issues/76-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-7'},
#  {'text': 'June 2021, issue 6',
#   'href': '/journal/10809/volumes-and-issues/76-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-6'},
#  {'text': 'May 2021, issue 5',
#   'href': '/journal/10809/volumes-and-issues/76-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-5'},
#  {'text': 'April 2021, issue 4',
#   'href': '/journal/10809/volumes-and-issues/76-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-4'},
#  {'text': 'March 2021, issue 3',
#   'href': '/journal/10809/volumes-and-issues/76-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-3'},
#  {'text': 'February 2021, issue 2',
#   'href': '/journal/10809/volumes-and-issues/76-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-2'},
#  {'text': 'January 2021, issue 1',
#   'href': '/journal/10809/volumes-and-issues/76-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/76-1'},
#  {'text': 'December 2020, issue 14',
#   'href': '/journal/10809/volumes-and-issues/75-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-14'},
#  {'text': 'December 2020, issue 13',
#   'href': '/journal/10809/volumes-and-issues/75-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-13'},
#  {'text': 'December 2020, issue 12',
#   'href': '/journal/10809/volumes-and-issues/75-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-12'},
#  {'text': 'November 2020, issue 11',
#   'href': '/journal/10809/volumes-and-issues/75-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-11'},
#  {'text': 'October 2020, issue 10',
#   'href': '/journal/10809/volumes-and-issues/75-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-10'},
#  {'text': 'September 2020, issue 9',
#   'href': '/journal/10809/volumes-and-issues/75-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-9'},
#  {'text': 'August 2020, issue 8',
#   'href': '/journal/10809/volumes-and-issues/75-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-8'},
#  {'text': 'July 2020, issue 7',
#   'href': '/journal/10809/volumes-and-issues/75-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-7'},
#  {'text': 'June 2020, issue 6',
#   'href': '/journal/10809/volumes-and-issues/75-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-6'},
#  {'text': 'May 2020, issue 5',
#   'href': '/journal/10809/volumes-and-issues/75-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-5'},
#  {'text': 'April 2020, issue 4',
#   'href': '/journal/10809/volumes-and-issues/75-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-4'},
#  {'text': 'March 2020, issue 3',
#   'href': '/journal/10809/volumes-and-issues/75-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-3'},
#  {'text': 'February 2020, issue 2',
#   'href': '/journal/10809/volumes-and-issues/75-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-2'},
#  {'text': 'January 2020, issue 1',
#   'href': '/journal/10809/volumes-and-issues/75-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/75-1'},
#  {'text': 'December 2019, issue 14',
#   'href': '/journal/10809/volumes-and-issues/74-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-14'},
#  {'text': 'December 2019, issue 13',
#   'href': '/journal/10809/volumes-and-issues/74-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-13'},
#  {'text': 'December 2019, issue 12',
#   'href': '/journal/10809/volumes-and-issues/74-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-12'},
#  {'text': 'November 2019, issue 11',
#   'href': '/journal/10809/volumes-and-issues/74-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-11'},
#  {'text': 'October 2019, issue 10',
#   'href': '/journal/10809/volumes-and-issues/74-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-10'},
#  {'text': 'September 2019, issue 9',
#   'href': '/journal/10809/volumes-and-issues/74-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-9'},
#  {'text': 'September 2019, issue 2',
#   'href': '/journal/10809/volumes-and-issues/74-2/supplement',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-2/supplement'},
#  {'text': 'August 2019, issue 8',
#   'href': '/journal/10809/volumes-and-issues/74-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-8'},
#  {'text': 'July 2019, issue 7',
#   'href': '/journal/10809/volumes-and-issues/74-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-7'},
#  {'text': 'July 2019, issue 1',
#   'href': '/journal/10809/volumes-and-issues/74-1/supplement',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-1/supplement'},
#  {'text': 'June 2019, issue 6',
#   'href': '/journal/10809/volumes-and-issues/74-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-6'},
#  {'text': 'May 2019, issue 5',
#   'href': '/journal/10809/volumes-and-issues/74-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-5'},
#  {'text': 'April 2019, issue 4',
#   'href': '/journal/10809/volumes-and-issues/74-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-4'},
#  {'text': 'March 2019, issue 3',
#   'href': '/journal/10809/volumes-and-issues/74-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-3'},
#  {'text': 'February 2019, issue 2',
#   'href': '/journal/10809/volumes-and-issues/74-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-2'},
#  {'text': 'January 2019, issue 1',
#   'href': '/journal/10809/volumes-and-issues/74-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/74-1'},
#  {'text': 'December 2018, issue 14',
#   'href': '/journal/10809/volumes-and-issues/73-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-14'},
#  {'text': 'December 2018, issue 13',
#   'href': '/journal/10809/volumes-and-issues/73-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-13'},
#  {'text': 'December 2018, issue 12',
#   'href': '/journal/10809/volumes-and-issues/73-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-12'},
#  {'text': 'November 2018, issue 11',
#   'href': '/journal/10809/volumes-and-issues/73-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-11'},
#  {'text': 'October 2018, issue 10',
#   'href': '/journal/10809/volumes-and-issues/73-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-10'},
#  {'text': 'September 2018, issue 9',
#   'href': '/journal/10809/volumes-and-issues/73-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-9'},
#  {'text': 'August 2018, issue 8',
#   'href': '/journal/10809/volumes-and-issues/73-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-8'},
#  {'text': 'July 2018, issue 7',
#   'href': '/journal/10809/volumes-and-issues/73-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-7'},
#  {'text': 'June 2018, issue 6',
#   'href': '/journal/10809/volumes-and-issues/73-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-6'},
#  {'text': 'May 2018, issue 5',
#   'href': '/journal/10809/volumes-and-issues/73-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-5'},
#  {'text': 'April 2018, issue 4',
#   'href': '/journal/10809/volumes-and-issues/73-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-4'},
#  {'text': 'March 2018, issue 3',
#   'href': '/journal/10809/volumes-and-issues/73-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-3'},
#  {'text': 'February 2018, issue 2',
#   'href': '/journal/10809/volumes-and-issues/73-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-2'},
#  {'text': 'January 2018, issue 1',
#   'href': '/journal/10809/volumes-and-issues/73-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/73-1'},
#  {'text': 'December 2017, issue 14',
#   'href': '/journal/10809/volumes-and-issues/72-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-14'},
#  {'text': 'December 2017, issue 13',
#   'href': '/journal/10809/volumes-and-issues/72-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-13'},
#  {'text': 'December 2017, issue 12',
#   'href': '/journal/10809/volumes-and-issues/72-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-12'},
#  {'text': 'November 2017, issue 11',
#   'href': '/journal/10809/volumes-and-issues/72-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-11'},
#  {'text': 'October 2017, issue 10',
#   'href': '/journal/10809/volumes-and-issues/72-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-10'},
#  {'text': 'September 2017, issue 9',
#   'href': '/journal/10809/volumes-and-issues/72-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-9'},
#  {'text': 'August 2017, issue 8',
#   'href': '/journal/10809/volumes-and-issues/72-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-8'},
#  {'text': 'July 2017, issue 7',
#   'href': '/journal/10809/volumes-and-issues/72-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-7'},
#  {'text': 'June 2017, issue 6',
#   'href': '/journal/10809/volumes-and-issues/72-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-6'},
#  {'text': 'May 2017, issue 5',
#   'href': '/journal/10809/volumes-and-issues/72-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-5'},
#  {'text': 'April 2017, issue 4',
#   'href': '/journal/10809/volumes-and-issues/72-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-4'},
#  {'text': 'March 2017, issue 3',
#   'href': '/journal/10809/volumes-and-issues/72-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-3'},
#  {'text': 'February 2017, issue 2',
#   'href': '/journal/10809/volumes-and-issues/72-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-2'},
#  {'text': 'January 2017, issue 1',
#   'href': '/journal/10809/volumes-and-issues/72-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/72-1'},
#  {'text': 'December 2016, issue 14',
#   'href': '/journal/10809/volumes-and-issues/71-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-14'},
#  {'text': 'December 2016, issue 13',
#   'href': '/journal/10809/volumes-and-issues/71-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-13'},
#  {'text': 'December 2016, issue 12',
#   'href': '/journal/10809/volumes-and-issues/71-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-12'},
#  {'text': 'November 2016, issue 11',
#   'href': '/journal/10809/volumes-and-issues/71-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-11'},
#  {'text': 'October 2016, issue 10',
#   'href': '/journal/10809/volumes-and-issues/71-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-10'},
#  {'text': 'September 2016, issue 9',
#   'href': '/journal/10809/volumes-and-issues/71-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-9'},
#  {'text': 'August 2016, issue 8',
#   'href': '/journal/10809/volumes-and-issues/71-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-8'},
#  {'text': 'July 2016, issue 7',
#   'href': '/journal/10809/volumes-and-issues/71-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-7'},
#  {'text': 'June 2016, issue 6',
#   'href': '/journal/10809/volumes-and-issues/71-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-6'},
#  {'text': 'May 2016, issue 5',
#   'href': '/journal/10809/volumes-and-issues/71-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-5'},
#  {'text': 'April 2016, issue 4',
#   'href': '/journal/10809/volumes-and-issues/71-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-4'},
#  {'text': 'March 2016, issue 3',
#   'href': '/journal/10809/volumes-and-issues/71-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-3'},
#  {'text': 'February 2016, issue 2',
#   'href': '/journal/10809/volumes-and-issues/71-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-2'},
#  {'text': 'January 2016, issue 1',
#   'href': '/journal/10809/volumes-and-issues/71-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/71-1'},
#  {'text': 'December 2015, issue 14',
#   'href': '/journal/10809/volumes-and-issues/70-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-14'},
#  {'text': 'December 2015, issue 13',
#   'href': '/journal/10809/volumes-and-issues/70-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-13'},
#  {'text': 'December 2015, issue 12',
#   'href': '/journal/10809/volumes-and-issues/70-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-12'},
#  {'text': 'November 2015, issue 11',
#   'href': '/journal/10809/volumes-and-issues/70-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-11'},
#  {'text': 'October 2015, issue 10',
#   'href': '/journal/10809/volumes-and-issues/70-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-10'},
#  {'text': 'September 2015, issue 9',
#   'href': '/journal/10809/volumes-and-issues/70-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-9'},
#  {'text': 'August 2015, issue 8',
#   'href': '/journal/10809/volumes-and-issues/70-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-8'},
#  {'text': 'July 2015, issue 7',
#   'href': '/journal/10809/volumes-and-issues/70-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-7'},
#  {'text': 'June 2015, issue 6',
#   'href': '/journal/10809/volumes-and-issues/70-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-6'},
#  {'text': 'May 2015, issue 5',
#   'href': '/journal/10809/volumes-and-issues/70-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-5'},
#  {'text': 'April 2015, issue 4',
#   'href': '/journal/10809/volumes-and-issues/70-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-4'},
#  {'text': 'March 2015, issue 3',
#   'href': '/journal/10809/volumes-and-issues/70-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-3'},
#  {'text': 'February 2015, issue 2',
#   'href': '/journal/10809/volumes-and-issues/70-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-2'},
#  {'text': 'January 2015, issue 1',
#   'href': '/journal/10809/volumes-and-issues/70-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/70-1'},
#  {'text': 'December 2014, issue 14',
#   'href': '/journal/10809/volumes-and-issues/69-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-14'},
#  {'text': 'December 2014, issue 13',
#   'href': '/journal/10809/volumes-and-issues/69-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-13'},
#  {'text': 'December 2014, issue 12',
#   'href': '/journal/10809/volumes-and-issues/69-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-12'},
#  {'text': 'November 2014, issue 11',
#   'href': '/journal/10809/volumes-and-issues/69-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-11'},
#  {'text': 'October 2014, issue 10',
#   'href': '/journal/10809/volumes-and-issues/69-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-10'},
#  {'text': 'September 2014, issue 9',
#   'href': '/journal/10809/volumes-and-issues/69-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-9'},
#  {'text': 'August 2014, issue 8',
#   'href': '/journal/10809/volumes-and-issues/69-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-8'},
#  {'text': 'July 2014, issue 7',
#   'href': '/journal/10809/volumes-and-issues/69-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-7'},
#  {'text': 'June 2014, issue 6',
#   'href': '/journal/10809/volumes-and-issues/69-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-6'},
#  {'text': 'May 2014, issue 5',
#   'href': '/journal/10809/volumes-and-issues/69-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-5'},
#  {'text': 'April 2014, issue 4',
#   'href': '/journal/10809/volumes-and-issues/69-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-4'},
#  {'text': 'March 2014, issue 3',
#   'href': '/journal/10809/volumes-and-issues/69-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-3'},
#  {'text': 'February 2014, issue 2',
#   'href': '/journal/10809/volumes-and-issues/69-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-2'},
#  {'text': 'January 2014, issue 1',
#   'href': '/journal/10809/volumes-and-issues/69-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/69-1'},
#  {'text': 'December 2013, issue 14',
#   'href': '/journal/10809/volumes-and-issues/68-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-14'},
#  {'text': 'December 2013, issue 13',
#   'href': '/journal/10809/volumes-and-issues/68-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-13'},
#  {'text': 'December 2013, issue 12',
#   'href': '/journal/10809/volumes-and-issues/68-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-12'},
#  {'text': 'November 2013, issue 11',
#   'href': '/journal/10809/volumes-and-issues/68-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-11'},
#  {'text': 'October 2013, issue 10',
#   'href': '/journal/10809/volumes-and-issues/68-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-10'},
#  {'text': 'September 2013, issue 9',
#   'href': '/journal/10809/volumes-and-issues/68-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-9'},
#  {'text': 'August 2013, issue 8',
#   'href': '/journal/10809/volumes-and-issues/68-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-8'},
#  {'text': 'July 2013, issue 7',
#   'href': '/journal/10809/volumes-and-issues/68-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-7'},
#  {'text': 'June 2013, issue 6',
#   'href': '/journal/10809/volumes-and-issues/68-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-6'},
#  {'text': 'May 2013, issue 5',
#   'href': '/journal/10809/volumes-and-issues/68-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-5'},
#  {'text': 'April 2013, issue 4',
#   'href': '/journal/10809/volumes-and-issues/68-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-4'},
#  {'text': 'March 2013, issue 3',
#   'href': '/journal/10809/volumes-and-issues/68-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-3'},
#  {'text': 'February 2013, issue 2',
#   'href': '/journal/10809/volumes-and-issues/68-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-2'},
#  {'text': 'January 2013, issue 1',
#   'href': '/journal/10809/volumes-and-issues/68-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/68-1'},
#  {'text': 'December 2012, issue 14',
#   'href': '/journal/10809/volumes-and-issues/67-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-14'},
#  {'text': 'December 2012, issue 13',
#   'href': '/journal/10809/volumes-and-issues/67-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-13'},
#  {'text': 'December 2012, issue 12',
#   'href': '/journal/10809/volumes-and-issues/67-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-12'},
#  {'text': 'November 2012, issue 11',
#   'href': '/journal/10809/volumes-and-issues/67-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-11'},
#  {'text': 'October 2012, issue 10',
#   'href': '/journal/10809/volumes-and-issues/67-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-10'},
#  {'text': 'September 2012, issue 9',
#   'href': '/journal/10809/volumes-and-issues/67-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-9'},
#  {'text': 'August 2012, issue 8',
#   'href': '/journal/10809/volumes-and-issues/67-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-8'},
#  {'text': 'July 2012, issue 7',
#   'href': '/journal/10809/volumes-and-issues/67-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-7'},
#  {'text': 'June 2012, issue 6',
#   'href': '/journal/10809/volumes-and-issues/67-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-6'},
#  {'text': 'May 2012, issue 5',
#   'href': '/journal/10809/volumes-and-issues/67-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-5'},
#  {'text': 'April 2012, issue 4',
#   'href': '/journal/10809/volumes-and-issues/67-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-4'},
#  {'text': 'March 2012, issue 3',
#   'href': '/journal/10809/volumes-and-issues/67-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-3'},
#  {'text': 'February 2012, issue 2',
#   'href': '/journal/10809/volumes-and-issues/67-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-2'},
#  {'text': 'January 2012, issue 1',
#   'href': '/journal/10809/volumes-and-issues/67-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/67-1'},
#  {'text': 'December 2011, issue 14',
#   'href': '/journal/10809/volumes-and-issues/66-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-14'},
#  {'text': 'December 2011, issue 13',
#   'href': '/journal/10809/volumes-and-issues/66-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-13'},
#  {'text': 'December 2011, issue 12',
#   'href': '/journal/10809/volumes-and-issues/66-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-12'},
#  {'text': 'November 2011, issue 11',
#   'href': '/journal/10809/volumes-and-issues/66-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-11'},
#  {'text': 'October 2011, issue 10',
#   'href': '/journal/10809/volumes-and-issues/66-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-10'},
#  {'text': 'September 2011, issue 9',
#   'href': '/journal/10809/volumes-and-issues/66-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-9'},
#  {'text': 'August 2011, issue 8',
#   'href': '/journal/10809/volumes-and-issues/66-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-8'},
#  {'text': 'July 2011, issue 7',
#   'href': '/journal/10809/volumes-and-issues/66-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-7'},
#  {'text': 'June 2011, issue 6',
#   'href': '/journal/10809/volumes-and-issues/66-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-6'},
#  {'text': 'May 2011, issue 5',
#   'href': '/journal/10809/volumes-and-issues/66-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-5'},
#  {'text': 'April 2011, issue 4',
#   'href': '/journal/10809/volumes-and-issues/66-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-4'},
#  {'text': 'March 2011, issue 3',
#   'href': '/journal/10809/volumes-and-issues/66-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-3'},
#  {'text': 'February 2011, issue 2',
#   'href': '/journal/10809/volumes-and-issues/66-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-2'},
#  {'text': 'January 2011, issue 1',
#   'href': '/journal/10809/volumes-and-issues/66-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/66-1'},
#  {'text': 'December 2010, issue 14',
#   'href': '/journal/10809/volumes-and-issues/65-14',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-14'},
#  {'text': 'December 2010, issue 13',
#   'href': '/journal/10809/volumes-and-issues/65-13',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-13'},
#  {'text': 'December 2010, issue 12',
#   'href': '/journal/10809/volumes-and-issues/65-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-12'},
#  {'text': 'November 2010, issue 11',
#   'href': '/journal/10809/volumes-and-issues/65-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-11'},
#  {'text': 'October 2010, issue 10',
#   'href': '/journal/10809/volumes-and-issues/65-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-10'},
#  {'text': 'September 2010, issue 9',
#   'href': '/journal/10809/volumes-and-issues/65-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-9'},
#  {'text': 'August 2010, issue 8',
#   'href': '/journal/10809/volumes-and-issues/65-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-8'},
#  {'text': 'July 2010, issue 7',
#   'href': '/journal/10809/volumes-and-issues/65-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-7'},
#  {'text': 'June 2010, issue 6',
#   'href': '/journal/10809/volumes-and-issues/65-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-6'},
#  {'text': 'May 2010, issue 5',
#   'href': '/journal/10809/volumes-and-issues/65-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-5'},
#  {'text': 'April 2010, issue 4',
#   'href': '/journal/10809/volumes-and-issues/65-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-4'},
#  {'text': 'March 2010, issue 3',
#   'href': '/journal/10809/volumes-and-issues/65-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-3'},
#  {'text': 'February 2010, issue 2',
#   'href': '/journal/10809/volumes-and-issues/65-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-2'},
#  {'text': 'January 2010, issue 1',
#   'href': '/journal/10809/volumes-and-issues/65-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/65-1'},
#  {'text': 'December 2009, issue 12',
#   'href': '/journal/10809/volumes-and-issues/64-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-12'},
#  {'text': 'November 2009, issue 11',
#   'href': '/journal/10809/volumes-and-issues/64-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-11'},
#  {'text': 'October 2009, issue 10',
#   'href': '/journal/10809/volumes-and-issues/64-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-10'},
#  {'text': 'September 2009, issue 9',
#   'href': '/journal/10809/volumes-and-issues/64-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-9'},
#  {'text': 'August 2009, issue 8',
#   'href': '/journal/10809/volumes-and-issues/64-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-8'},
#  {'text': 'July 2009, issue 7',
#   'href': '/journal/10809/volumes-and-issues/64-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-7'},
#  {'text': 'June 2009, issue 6',
#   'href': '/journal/10809/volumes-and-issues/64-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-6'},
#  {'text': 'May 2009, issue 5',
#   'href': '/journal/10809/volumes-and-issues/64-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-5'},
#  {'text': 'April 2009, issue 4',
#   'href': '/journal/10809/volumes-and-issues/64-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-4'},
#  {'text': 'March 2009, issue 3',
#   'href': '/journal/10809/volumes-and-issues/64-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-3'},
#  {'text': 'February 2009, issue 2',
#   'href': '/journal/10809/volumes-and-issues/64-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-2'},
#  {'text': 'January 2009, issue 1',
#   'href': '/journal/10809/volumes-and-issues/64-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/64-1'},
#  {'text': 'December 2008, issue 12',
#   'href': '/journal/10809/volumes-and-issues/63-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-12'},
#  {'text': 'November 2008, issue 11',
#   'href': '/journal/10809/volumes-and-issues/63-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-11'},
#  {'text': 'October 2008, issue 10',
#   'href': '/journal/10809/volumes-and-issues/63-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-10'},
#  {'text': 'September 2008, issue 9',
#   'href': '/journal/10809/volumes-and-issues/63-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-9'},
#  {'text': 'August 2008, issue 8',
#   'href': '/journal/10809/volumes-and-issues/63-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-8'},
#  {'text': 'July 2008, issue 7',
#   'href': '/journal/10809/volumes-and-issues/63-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-7'},
#  {'text': 'June 2008, issue 6',
#   'href': '/journal/10809/volumes-and-issues/63-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-6'},
#  {'text': 'May 2008, issue 5',
#   'href': '/journal/10809/volumes-and-issues/63-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-5'},
#  {'text': 'April 2008, issue 4',
#   'href': '/journal/10809/volumes-and-issues/63-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-4'},
#  {'text': 'March 2008, issue 3',
#   'href': '/journal/10809/volumes-and-issues/63-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-3'},
#  {'text': 'February 2008, issue 2',
#   'href': '/journal/10809/volumes-and-issues/63-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-2'},
#  {'text': 'January 2008, issue 1',
#   'href': '/journal/10809/volumes-and-issues/63-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/63-1'},
#  {'text': 'December 2007, issue 12',
#   'href': '/journal/10809/volumes-and-issues/62-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-12'},
#  {'text': 'November 2007, issue 11',
#   'href': '/journal/10809/volumes-and-issues/62-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-11'},
#  {'text': 'October 2007, issue 10',
#   'href': '/journal/10809/volumes-and-issues/62-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-10'},
#  {'text': 'September 2007, issue 9',
#   'href': '/journal/10809/volumes-and-issues/62-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-9'},
#  {'text': 'August 2007, issue 8',
#   'href': '/journal/10809/volumes-and-issues/62-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-8'},
#  {'text': 'July 2007, issue 7',
#   'href': '/journal/10809/volumes-and-issues/62-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-7'},
#  {'text': 'June 2007, issue 6',
#   'href': '/journal/10809/volumes-and-issues/62-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-6'},
#  {'text': 'May 2007, issue 5',
#   'href': '/journal/10809/volumes-and-issues/62-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-5'},
#  {'text': 'April 2007, issue 4',
#   'href': '/journal/10809/volumes-and-issues/62-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-4'},
#  {'text': 'March 2007, issue 3',
#   'href': '/journal/10809/volumes-and-issues/62-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-3'},
#  {'text': 'February 2007, issue 2',
#   'href': '/journal/10809/volumes-and-issues/62-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-2'},
#  {'text': 'January 2007, issue 1',
#   'href': '/journal/10809/volumes-and-issues/62-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/62-1'},
#  {'text': 'December 2006, issue 12',
#   'href': '/journal/10809/volumes-and-issues/61-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-12'},
#  {'text': 'November 2006, issue 11',
#   'href': '/journal/10809/volumes-and-issues/61-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-11'},
#  {'text': 'October 2006, issue 10',
#   'href': '/journal/10809/volumes-and-issues/61-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-10'},
#  {'text': 'September 2006, issue 9',
#   'href': '/journal/10809/volumes-and-issues/61-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-9'},
#  {'text': 'September 2006, issue 5',
#   'href': '/journal/10809/volumes-and-issues/61-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-5'},
#  {'text': 'August 2006, issue 8',
#   'href': '/journal/10809/volumes-and-issues/61-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-8'},
#  {'text': 'July 2006, issue 7',
#   'href': '/journal/10809/volumes-and-issues/61-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-7'},
#  {'text': 'June 2006, issue 6',
#   'href': '/journal/10809/volumes-and-issues/61-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-6'},
#  {'text': 'April 2006, issue 4',
#   'href': '/journal/10809/volumes-and-issues/61-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-4'},
#  {'text': 'March 2006, issue 3',
#   'href': '/journal/10809/volumes-and-issues/61-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-3'},
#  {'text': 'February 2006, issue 2',
#   'href': '/journal/10809/volumes-and-issues/61-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-2'},
#  {'text': 'January 2006, issue 1',
#   'href': '/journal/10809/volumes-and-issues/61-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/61-1'},
#  {'text': 'December 2005, issue 12',
#   'href': '/journal/10809/volumes-and-issues/60-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-12'},
#  {'text': 'November 2005, issue 11',
#   'href': '/journal/10809/volumes-and-issues/60-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-11'},
#  {'text': 'October 2005, issue 10',
#   'href': '/journal/10809/volumes-and-issues/60-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-10'},
#  {'text': 'September 2005, issue 9',
#   'href': '/journal/10809/volumes-and-issues/60-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-9'},
#  {'text': 'August 2005, issue 8',
#   'href': '/journal/10809/volumes-and-issues/60-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-8'},
#  {'text': 'July 2005, issue 7',
#   'href': '/journal/10809/volumes-and-issues/60-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-7'},
#  {'text': 'June 2005, issue 6',
#   'href': '/journal/10809/volumes-and-issues/60-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-6'},
#  {'text': 'May 2005, issue 5',
#   'href': '/journal/10809/volumes-and-issues/60-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-5'},
#  {'text': 'April 2005, issue 4',
#   'href': '/journal/10809/volumes-and-issues/60-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-4'},
#  {'text': 'March 2005, issue 3',
#   'href': '/journal/10809/volumes-and-issues/60-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-3'},
#  {'text': 'February 2005, issue 2',
#   'href': '/journal/10809/volumes-and-issues/60-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-2'},
#  {'text': 'January 2005, issue 1',
#   'href': '/journal/10809/volumes-and-issues/60-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/60-1'},
#  {'text': 'December 2004, issue 12',
#   'href': '/journal/10809/volumes-and-issues/59-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-12'},
#  {'text': 'November 2004, issue 11',
#   'href': '/journal/10809/volumes-and-issues/59-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-11'},
#  {'text': 'October 2004, issue 10',
#   'href': '/journal/10809/volumes-and-issues/59-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-10'},
#  {'text': 'September 2004, issue 9',
#   'href': '/journal/10809/volumes-and-issues/59-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-9'},
#  {'text': 'August 2004, issue 8',
#   'href': '/journal/10809/volumes-and-issues/59-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-8'},
#  {'text': 'July 2004, issue 7',
#   'href': '/journal/10809/volumes-and-issues/59-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-7'},
#  {'text': 'June 2004, issue 6',
#   'href': '/journal/10809/volumes-and-issues/59-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-6'},
#  {'text': 'May 2004, issue 5',
#   'href': '/journal/10809/volumes-and-issues/59-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-5'},
#  {'text': 'April 2004, issue 4',
#   'href': '/journal/10809/volumes-and-issues/59-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-4'},
#  {'text': 'March 2004, issue 3',
#   'href': '/journal/10809/volumes-and-issues/59-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-3'},
#  {'text': 'February 2004, issue 2',
#   'href': '/journal/10809/volumes-and-issues/59-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-2'},
#  {'text': 'January 2004, issue 1',
#   'href': '/journal/10809/volumes-and-issues/59-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/59-1'},
#  {'text': 'December 2003, issue 12',
#   'href': '/journal/10809/volumes-and-issues/58-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-12'},
#  {'text': 'November 2003, issue 11',
#   'href': '/journal/10809/volumes-and-issues/58-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-11'},
#  {'text': 'October 2003, issue 10',
#   'href': '/journal/10809/volumes-and-issues/58-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-10'},
#  {'text': 'September 2003, issue 9',
#   'href': '/journal/10809/volumes-and-issues/58-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-9'},
#  {'text': 'August 2003, issue 8',
#   'href': '/journal/10809/volumes-and-issues/58-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-8'},
#  {'text': 'July 2003, issue 7',
#   'href': '/journal/10809/volumes-and-issues/58-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-7'},
#  {'text': 'June 2003, issue 6',
#   'href': '/journal/10809/volumes-and-issues/58-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-6'},
#  {'text': 'May 2003, issue 5',
#   'href': '/journal/10809/volumes-and-issues/58-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-5'},
#  {'text': 'April 2003, issue 4',
#   'href': '/journal/10809/volumes-and-issues/58-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-4'},
#  {'text': 'March 2003, issue 3',
#   'href': '/journal/10809/volumes-and-issues/58-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-3'},
#  {'text': 'February 2003, issue 2',
#   'href': '/journal/10809/volumes-and-issues/58-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-2'},
#  {'text': 'January 2003, issue 1',
#   'href': '/journal/10809/volumes-and-issues/58-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/58-1'},
#  {'text': 'December 2002, issue 12',
#   'href': '/journal/10809/volumes-and-issues/57-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-12'},
#  {'text': 'November 2002, issue 11',
#   'href': '/journal/10809/volumes-and-issues/57-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-11'},
#  {'text': 'October 2002, issue 10',
#   'href': '/journal/10809/volumes-and-issues/57-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-10'},
#  {'text': 'September 2002, issue 9',
#   'href': '/journal/10809/volumes-and-issues/57-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-9'},
#  {'text': 'August 2002, issue 8',
#   'href': '/journal/10809/volumes-and-issues/57-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-8'},
#  {'text': 'July 2002, issue 7',
#   'href': '/journal/10809/volumes-and-issues/57-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-7'},
#  {'text': 'June 2002, issue 6',
#   'href': '/journal/10809/volumes-and-issues/57-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-6'},
#  {'text': 'May 2002, issue 5',
#   'href': '/journal/10809/volumes-and-issues/57-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-5'},
#  {'text': 'April 2002, issue 4',
#   'href': '/journal/10809/volumes-and-issues/57-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-4'},
#  {'text': 'March 2002, issue 3',
#   'href': '/journal/10809/volumes-and-issues/57-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-3'},
#  {'text': 'February 2002, issue 2',
#   'href': '/journal/10809/volumes-and-issues/57-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-2'},
#  {'text': 'January 2002, issue 1',
#   'href': '/journal/10809/volumes-and-issues/57-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/57-1'},
#  {'text': 'December 2001, issue 12',
#   'href': '/journal/10809/volumes-and-issues/56-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-12'},
#  {'text': 'November 2001, issue 11',
#   'href': '/journal/10809/volumes-and-issues/56-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-11'},
#  {'text': 'October 2001, issue 10',
#   'href': '/journal/10809/volumes-and-issues/56-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-10'},
#  {'text': 'September 2001, issue 9',
#   'href': '/journal/10809/volumes-and-issues/56-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-9'},
#  {'text': 'August 2001, issue 8',
#   'href': '/journal/10809/volumes-and-issues/56-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-8'},
#  {'text': 'July 2001, issue 7',
#   'href': '/journal/10809/volumes-and-issues/56-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-7'},
#  {'text': 'June 2001, issue 6',
#   'href': '/journal/10809/volumes-and-issues/56-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-6'},
#  {'text': 'May 2001, issue 5',
#   'href': '/journal/10809/volumes-and-issues/56-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-5'},
#  {'text': 'April 2001, issue 4',
#   'href': '/journal/10809/volumes-and-issues/56-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-4'},
#  {'text': 'March 2001, issue 3',
#   'href': '/journal/10809/volumes-and-issues/56-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-3'},
#  {'text': 'February 2001, issue 2',
#   'href': '/journal/10809/volumes-and-issues/56-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-2'},
#  {'text': 'January 2001, issue 1',
#   'href': '/journal/10809/volumes-and-issues/56-1',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/56-1'},
#  {'text': 'December 2000, issue 12',
#   'href': '/journal/10809/volumes-and-issues/55-12',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-12'},
#  {'text': 'November 2000, issue 11',
#   'href': '/journal/10809/volumes-and-issues/55-11',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-11'},
#  {'text': 'October 2000, issue 10',
#   'href': '/journal/10809/volumes-and-issues/55-10',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-10'},
#  {'text': 'September 2000, issue 9',
#   'href': '/journal/10809/volumes-and-issues/55-9',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-9'},
#  {'text': 'August 2000, issue 8',
#   'href': '/journal/10809/volumes-and-issues/55-8',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-8'},
#  {'text': 'July 2000, issue 7',
#   'href': '/journal/10809/volumes-and-issues/55-7',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-7'},
#  {'text': 'June 2000, issue 6',
#   'href': '/journal/10809/volumes-and-issues/55-6',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-6'},
#  {'text': 'May 2000, issue 5',
#   'href': '/journal/10809/volumes-and-issues/55-5',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-5'},
#  {'text': 'April 2000, issue 4',
#   'href': '/journal/10809/volumes-and-issues/55-4',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-4'},
#  {'text': 'March 2000, issue 3',
#   'href': '/journal/10809/volumes-and-issues/55-3',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-3'},
#  {'text': 'February 2000, issue 2',
#   'href': '/journal/10809/volumes-and-issues/55-2',
#   'url': 'https://link.springer.com/journal/10809/volumes-and-issues/55-2'}]

# %%
high_catalogue
# Out:
# [{'text': 'September 2023, issue 21',
#   'href': '/journal/216/volumes-and-issues/415-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-21'},
#  {'text': 'August 2023, issue 20',
#   'href': '/journal/216/volumes-and-issues/415-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-20'},
#  {'text': 'August 2023, issue 19',
#   'href': '/journal/216/volumes-and-issues/415-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-19'},
#  {'text': 'July 2023, issue 18',
#   'href': '/journal/216/volumes-and-issues/415-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-18'},
#  {'text': 'July 2023, issue 17',
#   'href': '/journal/216/volumes-and-issues/415-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-17'},
#  {'text': 'July 2023, issue 16',
#   'href': '/journal/216/volumes-and-issues/415-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-16'},
#  {'text': 'June 2023, issue 15',
#   'href': '/journal/216/volumes-and-issues/415-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-15'},
#  {'text': 'June 2023, issue 14',
#   'href': '/journal/216/volumes-and-issues/415-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-14'},
#  {'text': 'May 2023, issue 13',
#   'href': '/journal/216/volumes-and-issues/415-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-13'},
#  {'text': 'May 2023, issue 12',
#   'href': '/journal/216/volumes-and-issues/415-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-12'},
#  {'text': 'May 2023, issue 11',
#   'href': '/journal/216/volumes-and-issues/415-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-11'},
#  {'text': 'April 2023, issue 10',
#   'href': '/journal/216/volumes-and-issues/415-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-10'},
#  {'text': 'April 2023, issue 9',
#   'href': '/journal/216/volumes-and-issues/415-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-9'},
#  {'text': 'March 2023, issue 8',
#   'href': '/journal/216/volumes-and-issues/415-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-8'},
#  {'text': 'March 2023, issue 7',
#   'href': '/journal/216/volumes-and-issues/415-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-7'},
#  {'text': 'March 2023, issue 6',
#   'href': '/journal/216/volumes-and-issues/415-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-6'},
#  {'text': 'February 2023, issue 5',
#   'href': '/journal/216/volumes-and-issues/415-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-5'},
#  {'text': 'February 2023, issue 4',
#   'href': '/journal/216/volumes-and-issues/415-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-4'},
#  {'text': 'January 2023, issue 3',
#   'href': '/journal/216/volumes-and-issues/415-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-3'},
#  {'text': 'January 2023, issue 2',
#   'href': '/journal/216/volumes-and-issues/415-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-2'},
#  {'text': 'January 2023, issue 1',
#   'href': '/journal/216/volumes-and-issues/415-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/415-1'},
#  {'text': 'December 2022, issue 29-30',
#   'href': '/journal/216/volumes-and-issues/414-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-29'},
#  {'text': 'November 2022, issue 28',
#   'href': '/journal/216/volumes-and-issues/414-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-28'},
#  {'text': 'November 2022, issue 27',
#   'href': '/journal/216/volumes-and-issues/414-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-27'},
#  {'text': 'November 2022, issue 26',
#   'href': '/journal/216/volumes-and-issues/414-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-26'},
#  {'text': 'October 2022, issue 25',
#   'href': '/journal/216/volumes-and-issues/414-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-25'},
#  {'text': 'October 2022, issue 24',
#   'href': '/journal/216/volumes-and-issues/414-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-24'},
#  {'text': 'September 2022, issue 23',
#   'href': '/journal/216/volumes-and-issues/414-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-23'},
#  {'text': 'September 2022, issue 22',
#   'href': '/journal/216/volumes-and-issues/414-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-22'},
#  {'text': 'September 2022, issue 21',
#   'href': '/journal/216/volumes-and-issues/414-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-21'},
#  {'text': 'August 2022, issue 20',
#   'href': '/journal/216/volumes-and-issues/414-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-20'},
#  {'text': 'August 2022, issue 19',
#   'href': '/journal/216/volumes-and-issues/414-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-19'},
#  {'text': 'July 2022, issue 18',
#   'href': '/journal/216/volumes-and-issues/414-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-18'},
#  {'text': 'July 2022, issue 17',
#   'href': '/journal/216/volumes-and-issues/414-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-17'},
#  {'text': 'July 2022, issue 16',
#   'href': '/journal/216/volumes-and-issues/414-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-16'},
#  {'text': 'June 2022, issue 15',
#   'href': '/journal/216/volumes-and-issues/414-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-15'},
#  {'text': 'June 2022, issue 14',
#   'href': '/journal/216/volumes-and-issues/414-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-14'},
#  {'text': 'May 2022, issue 13',
#   'href': '/journal/216/volumes-and-issues/414-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-13'},
#  {'text': 'May 2022, issue 12',
#   'href': '/journal/216/volumes-and-issues/414-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-12'},
#  {'text': 'May 2022, issue 11',
#   'href': '/journal/216/volumes-and-issues/414-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-11'},
#  {'text': 'April 2022, issue 10',
#   'href': '/journal/216/volumes-and-issues/414-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-10'},
#  {'text': 'April 2022, issue 9',
#   'href': '/journal/216/volumes-and-issues/414-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-9'},
#  {'text': 'March 2022, issue 8',
#   'href': '/journal/216/volumes-and-issues/414-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-8'},
#  {'text': 'March 2022, issue 7',
#   'href': '/journal/216/volumes-and-issues/414-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-7'},
#  {'text': 'March 2022, issue 6',
#   'href': '/journal/216/volumes-and-issues/414-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-6'},
#  {'text': 'February 2022, issue 5',
#   'href': '/journal/216/volumes-and-issues/414-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-5'},
#  {'text': 'February 2022, issue 4',
#   'href': '/journal/216/volumes-and-issues/414-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-4'},
#  {'text': 'January 2022, issue 3',
#   'href': '/journal/216/volumes-and-issues/414-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-3'},
#  {'text': 'January 2022, issue 2',
#   'href': '/journal/216/volumes-and-issues/414-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-2'},
#  {'text': 'January 2022, issue 1',
#   'href': '/journal/216/volumes-and-issues/414-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/414-1'},
#  {'text': 'December 2021, issue 30',
#   'href': '/journal/216/volumes-and-issues/413-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-30'},
#  {'text': 'December 2021, issue 29',
#   'href': '/journal/216/volumes-and-issues/413-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-29'},
#  {'text': 'November 2021, issue 28',
#   'href': '/journal/216/volumes-and-issues/413-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-28'},
#  {'text': 'November 2021, issue 27',
#   'href': '/journal/216/volumes-and-issues/413-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-27'},
#  {'text': 'November 2021, issue 26',
#   'href': '/journal/216/volumes-and-issues/413-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-26'},
#  {'text': 'October 2021, issue 25',
#   'href': '/journal/216/volumes-and-issues/413-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-25'},
#  {'text': 'October 2021, issue 24',
#   'href': '/journal/216/volumes-and-issues/413-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-24'},
#  {'text': 'September 2021, issue 23',
#   'href': '/journal/216/volumes-and-issues/413-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-23'},
#  {'text': 'September 2021, issue 22',
#   'href': '/journal/216/volumes-and-issues/413-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-22'},
#  {'text': 'September 2021, issue 21',
#   'href': '/journal/216/volumes-and-issues/413-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-21'},
#  {'text': 'August 2021, issue 20',
#   'href': '/journal/216/volumes-and-issues/413-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-20'},
#  {'text': 'August 2021, issue 19',
#   'href': '/journal/216/volumes-and-issues/413-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-19'},
#  {'text': 'July 2021, issue 18',
#   'href': '/journal/216/volumes-and-issues/413-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-18'},
#  {'text': 'July 2021, issue 17',
#   'href': '/journal/216/volumes-and-issues/413-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-17'},
#  {'text': 'July 2021, issue 16',
#   'href': '/journal/216/volumes-and-issues/413-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-16'},
#  {'text': 'June 2021, issue 15',
#   'href': '/journal/216/volumes-and-issues/413-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-15'},
#  {'text': 'June 2021, issue 14',
#   'href': '/journal/216/volumes-and-issues/413-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-14'},
#  {'text': 'May 2021, issue 13',
#   'href': '/journal/216/volumes-and-issues/413-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-13'},
#  {'text': 'May 2021, issue 12',
#   'href': '/journal/216/volumes-and-issues/413-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-12'},
#  {'text': 'May 2021, issue 11',
#   'href': '/journal/216/volumes-and-issues/413-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-11'},
#  {'text': 'April 2021, issue 10',
#   'href': '/journal/216/volumes-and-issues/413-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-10'},
#  {'text': 'April 2021, issue 9',
#   'href': '/journal/216/volumes-and-issues/413-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-9'},
#  {'text': 'March 2021, issue 8',
#   'href': '/journal/216/volumes-and-issues/413-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-8'},
#  {'text': 'March 2021, issue 7',
#   'href': '/journal/216/volumes-and-issues/413-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-7'},
#  {'text': 'March 2021, issue 6',
#   'href': '/journal/216/volumes-and-issues/413-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-6'},
#  {'text': 'February 2021, issue 5',
#   'href': '/journal/216/volumes-and-issues/413-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-5'},
#  {'text': 'February 2021, issue 4',
#   'href': '/journal/216/volumes-and-issues/413-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-4'},
#  {'text': 'January 2021, issue 3',
#   'href': '/journal/216/volumes-and-issues/413-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-3'},
#  {'text': 'January 2021, issue 2',
#   'href': '/journal/216/volumes-and-issues/413-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-2'},
#  {'text': 'January 2021, issue 1',
#   'href': '/journal/216/volumes-and-issues/413-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/413-1'},
#  {'text': 'December 2020, issue 30',
#   'href': '/journal/216/volumes-and-issues/412-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-30'},
#  {'text': 'November 2020, issue 29',
#   'href': '/journal/216/volumes-and-issues/412-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-29'},
#  {'text': 'November 2020, issue 28',
#   'href': '/journal/216/volumes-and-issues/412-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-28'},
#  {'text': 'November 2020, issue 27',
#   'href': '/journal/216/volumes-and-issues/412-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-27'},
#  {'text': 'October 2020, issue 26',
#   'href': '/journal/216/volumes-and-issues/412-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-26'},
#  {'text': 'October 2020, issue 25',
#   'href': '/journal/216/volumes-and-issues/412-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-25'},
#  {'text': 'September 2020, issue 24',
#   'href': '/journal/216/volumes-and-issues/412-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-24'},
#  {'text': 'September 2020, issue 23',
#   'href': '/journal/216/volumes-and-issues/412-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-23'},
#  {'text': 'September 2020, issue 22',
#   'href': '/journal/216/volumes-and-issues/412-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-22'},
#  {'text': 'August 2020, issue 21',
#   'href': '/journal/216/volumes-and-issues/412-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-21'},
#  {'text': 'August 2020, issue 20',
#   'href': '/journal/216/volumes-and-issues/412-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-20'},
#  {'text': 'July 2020, issue 19',
#   'href': '/journal/216/volumes-and-issues/412-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-19'},
#  {'text': 'July 2020, issue 18',
#   'href': '/journal/216/volumes-and-issues/412-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-18'},
#  {'text': 'July 2020, issue 17',
#   'href': '/journal/216/volumes-and-issues/412-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-17'},
#  {'text': 'June 2020, issue 16',
#   'href': '/journal/216/volumes-and-issues/412-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-16'},
#  {'text': 'June 2020, issue 15',
#   'href': '/journal/216/volumes-and-issues/412-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-15'},
#  {'text': 'May 2020, issue 14',
#   'href': '/journal/216/volumes-and-issues/412-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-14'},
#  {'text': 'May 2020, issue 13',
#   'href': '/journal/216/volumes-and-issues/412-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-13'},
#  {'text': 'May 2020, issue 12',
#   'href': '/journal/216/volumes-and-issues/412-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-12'},
#  {'text': 'April 2020, issue 11',
#   'href': '/journal/216/volumes-and-issues/412-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-11'},
#  {'text': 'April 2020, issue 10',
#   'href': '/journal/216/volumes-and-issues/412-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-10'},
#  {'text': 'April 2020, issue 9',
#   'href': '/journal/216/volumes-and-issues/412-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-9'},
#  {'text': 'March 2020, issue 8',
#   'href': '/journal/216/volumes-and-issues/412-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-8'},
#  {'text': 'March 2020, issue 7',
#   'href': '/journal/216/volumes-and-issues/412-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-7'},
#  {'text': 'February 2020, issue 6',
#   'href': '/journal/216/volumes-and-issues/412-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-6'},
#  {'text': 'February 2020, issue 5',
#   'href': '/journal/216/volumes-and-issues/412-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-5'},
#  {'text': 'February 2020, issue 4',
#   'href': '/journal/216/volumes-and-issues/412-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-4'},
#  {'text': 'January 2020, issue 3',
#   'href': '/journal/216/volumes-and-issues/412-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-3'},
#  {'text': 'January 2020, issue 2',
#   'href': '/journal/216/volumes-and-issues/412-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-2'},
#  {'text': 'January 2020, issue 1',
#   'href': '/journal/216/volumes-and-issues/412-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/412-1'},
#  {'text': 'December 2019, issue 30',
#   'href': '/journal/216/volumes-and-issues/411-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-30'},
#  {'text': 'November 2019, issue 29',
#   'href': '/journal/216/volumes-and-issues/411-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-29'},
#  {'text': 'November 2019, issue 28',
#   'href': '/journal/216/volumes-and-issues/411-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-28'},
#  {'text': 'November 2019, issue 27',
#   'href': '/journal/216/volumes-and-issues/411-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-27'},
#  {'text': 'October 2019, issue 26',
#   'href': '/journal/216/volumes-and-issues/411-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-26'},
#  {'text': 'October 2019, issue 25',
#   'href': '/journal/216/volumes-and-issues/411-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-25'},
#  {'text': 'September 2019, issue 24',
#   'href': '/journal/216/volumes-and-issues/411-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-24'},
#  {'text': 'September 2019, issue 23',
#   'href': '/journal/216/volumes-and-issues/411-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-23'},
#  {'text': 'September 2019, issue 22',
#   'href': '/journal/216/volumes-and-issues/411-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-22'},
#  {'text': 'August 2019, issue 21',
#   'href': '/journal/216/volumes-and-issues/411-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-21'},
#  {'text': 'August 2019, issue 20',
#   'href': '/journal/216/volumes-and-issues/411-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-20'},
#  {'text': 'July 2019, issue 19',
#   'href': '/journal/216/volumes-and-issues/411-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-19'},
#  {'text': 'July 2019, issue 18',
#   'href': '/journal/216/volumes-and-issues/411-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-18'},
#  {'text': 'July 2019, issue 17',
#   'href': '/journal/216/volumes-and-issues/411-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-17'},
#  {'text': 'June 2019, issue 16',
#   'href': '/journal/216/volumes-and-issues/411-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-16'},
#  {'text': 'June 2019, issue 15',
#   'href': '/journal/216/volumes-and-issues/411-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-15'},
#  {'text': 'May 2019, issue 14',
#   'href': '/journal/216/volumes-and-issues/411-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-14'},
#  {'text': 'May 2019, issue 13',
#   'href': '/journal/216/volumes-and-issues/411-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-13'},
#  {'text': 'May 2019, issue 12',
#   'href': '/journal/216/volumes-and-issues/411-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-12'},
#  {'text': 'April 2019, issue 11',
#   'href': '/journal/216/volumes-and-issues/411-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-11'},
#  {'text': 'April 2019, issue 10',
#   'href': '/journal/216/volumes-and-issues/411-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-10'},
#  {'text': 'March 2019, issue 9',
#   'href': '/journal/216/volumes-and-issues/411-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-9'},
#  {'text': 'March 2019, issue 8',
#   'href': '/journal/216/volumes-and-issues/411-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-8'},
#  {'text': 'March 2019, issue 7',
#   'href': '/journal/216/volumes-and-issues/411-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-7'},
#  {'text': 'February 2019, issue 6',
#   'href': '/journal/216/volumes-and-issues/411-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-6'},
#  {'text': 'February 2019, issue 5',
#   'href': '/journal/216/volumes-and-issues/411-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-5'},
#  {'text': 'February 2019, issue 4',
#   'href': '/journal/216/volumes-and-issues/411-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-4'},
#  {'text': 'January 2019, issue 3',
#   'href': '/journal/216/volumes-and-issues/411-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-3'},
#  {'text': 'January 2019, issue 2',
#   'href': '/journal/216/volumes-and-issues/411-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-2'},
#  {'text': 'January 2019, issue 1',
#   'href': '/journal/216/volumes-and-issues/411-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/411-1'},
#  {'text': 'December 2018, issue 30',
#   'href': '/journal/216/volumes-and-issues/410-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-30'},
#  {'text': 'November 2018, issue 29',
#   'href': '/journal/216/volumes-and-issues/410-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-29'},
#  {'text': 'November 2018, issue 28',
#   'href': '/journal/216/volumes-and-issues/410-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-28'},
#  {'text': 'November 2018, issue 27',
#   'href': '/journal/216/volumes-and-issues/410-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-27'},
#  {'text': 'October 2018, issue 26',
#   'href': '/journal/216/volumes-and-issues/410-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-26'},
#  {'text': 'October 2018, issue 25',
#   'href': '/journal/216/volumes-and-issues/410-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-25'},
#  {'text': 'September 2018, issue 24',
#   'href': '/journal/216/volumes-and-issues/410-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-24'},
#  {'text': 'September 2018, issue 23',
#   'href': '/journal/216/volumes-and-issues/410-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-23'},
#  {'text': 'September 2018, issue 22',
#   'href': '/journal/216/volumes-and-issues/410-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-22'},
#  {'text': 'August 2018, issue 21',
#   'href': '/journal/216/volumes-and-issues/410-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-21'},
#  {'text': 'August 2018, issue 20',
#   'href': '/journal/216/volumes-and-issues/410-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-20'},
#  {'text': 'July 2018, issue 19',
#   'href': '/journal/216/volumes-and-issues/410-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-19'},
#  {'text': 'July 2018, issue 18',
#   'href': '/journal/216/volumes-and-issues/410-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-18'},
#  {'text': 'July 2018, issue 17',
#   'href': '/journal/216/volumes-and-issues/410-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-17'},
#  {'text': 'June 2018, issue 16',
#   'href': '/journal/216/volumes-and-issues/410-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-16'},
#  {'text': 'June 2018, issue 15',
#   'href': '/journal/216/volumes-and-issues/410-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-15'},
#  {'text': 'May 2018, issue 14',
#   'href': '/journal/216/volumes-and-issues/410-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-14'},
#  {'text': 'May 2018, issue 13',
#   'href': '/journal/216/volumes-and-issues/410-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-13'},
#  {'text': 'May 2018, issue 12',
#   'href': '/journal/216/volumes-and-issues/410-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-12'},
#  {'text': 'April 2018, issue 11',
#   'href': '/journal/216/volumes-and-issues/410-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-11'},
#  {'text': 'April 2018, issue 10',
#   'href': '/journal/216/volumes-and-issues/410-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-10'},
#  {'text': 'March 2018, issue 9',
#   'href': '/journal/216/volumes-and-issues/410-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-9'},
#  {'text': 'March 2018, issue 8',
#   'href': '/journal/216/volumes-and-issues/410-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-8'},
#  {'text': 'March 2018, issue 7',
#   'href': '/journal/216/volumes-and-issues/410-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-7'},
#  {'text': 'February 2018, issue 6',
#   'href': '/journal/216/volumes-and-issues/410-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-6'},
#  {'text': 'February 2018, issue 5',
#   'href': '/journal/216/volumes-and-issues/410-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-5'},
#  {'text': 'February 2018, issue 4',
#   'href': '/journal/216/volumes-and-issues/410-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-4'},
#  {'text': 'January 2018, issue 3',
#   'href': '/journal/216/volumes-and-issues/410-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-3'},
#  {'text': 'January 2018, issue 2',
#   'href': '/journal/216/volumes-and-issues/410-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-2'},
#  {'text': 'January 2018, issue 1',
#   'href': '/journal/216/volumes-and-issues/410-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/410-1'},
#  {'text': 'December 2017, issue 30',
#   'href': '/journal/216/volumes-and-issues/409-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-30'},
#  {'text': 'November 2017, issue 29',
#   'href': '/journal/216/volumes-and-issues/409-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-29'},
#  {'text': 'November 2017, issue 28',
#   'href': '/journal/216/volumes-and-issues/409-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-28'},
#  {'text': 'November 2017, issue 27',
#   'href': '/journal/216/volumes-and-issues/409-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-27'},
#  {'text': 'October 2017, issue 26',
#   'href': '/journal/216/volumes-and-issues/409-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-26'},
#  {'text': 'October 2017, issue 25',
#   'href': '/journal/216/volumes-and-issues/409-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-25'},
#  {'text': 'September 2017, issue 24',
#   'href': '/journal/216/volumes-and-issues/409-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-24'},
#  {'text': 'September 2017, issue 23',
#   'href': '/journal/216/volumes-and-issues/409-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-23'},
#  {'text': 'September 2017, issue 22',
#   'href': '/journal/216/volumes-and-issues/409-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-22'},
#  {'text': 'August 2017, issue 21',
#   'href': '/journal/216/volumes-and-issues/409-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-21'},
#  {'text': 'August 2017, issue 20',
#   'href': '/journal/216/volumes-and-issues/409-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-20'},
#  {'text': 'July 2017, issue 19',
#   'href': '/journal/216/volumes-and-issues/409-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-19'},
#  {'text': 'July 2017, issue 18',
#   'href': '/journal/216/volumes-and-issues/409-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-18'},
#  {'text': 'July 2017, issue 17',
#   'href': '/journal/216/volumes-and-issues/409-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-17'},
#  {'text': 'June 2017, issue 16',
#   'href': '/journal/216/volumes-and-issues/409-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-16'},
#  {'text': 'June 2017, issue 15',
#   'href': '/journal/216/volumes-and-issues/409-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-15'},
#  {'text': 'May 2017, issue 14',
#   'href': '/journal/216/volumes-and-issues/409-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-14'},
#  {'text': 'May 2017, issue 13',
#   'href': '/journal/216/volumes-and-issues/409-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-13'},
#  {'text': 'May 2017, issue 12',
#   'href': '/journal/216/volumes-and-issues/409-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-12'},
#  {'text': 'April 2017, issue 11',
#   'href': '/journal/216/volumes-and-issues/409-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-11'},
#  {'text': 'April 2017, issue 10',
#   'href': '/journal/216/volumes-and-issues/409-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-10'},
#  {'text': 'March 2017, issue 9',
#   'href': '/journal/216/volumes-and-issues/409-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-9'},
#  {'text': 'March 2017, issue 8',
#   'href': '/journal/216/volumes-and-issues/409-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-8'},
#  {'text': 'March 2017, issue 7',
#   'href': '/journal/216/volumes-and-issues/409-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-7'},
#  {'text': 'February 2017, issue 6',
#   'href': '/journal/216/volumes-and-issues/409-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-6'},
#  {'text': 'February 2017, issue 5',
#   'href': '/journal/216/volumes-and-issues/409-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-5'},
#  {'text': 'February 2017, issue 4',
#   'href': '/journal/216/volumes-and-issues/409-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-4'},
#  {'text': 'January 2017, issue 3',
#   'href': '/journal/216/volumes-and-issues/409-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-3'},
#  {'text': 'January 2017, issue 2',
#   'href': '/journal/216/volumes-and-issues/409-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-2'},
#  {'text': 'January 2017, issue 1',
#   'href': '/journal/216/volumes-and-issues/409-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/409-1'},
#  {'text': 'December 2016, issue 30',
#   'href': '/journal/216/volumes-and-issues/408-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-30'},
#  {'text': 'November 2016, issue 29',
#   'href': '/journal/216/volumes-and-issues/408-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-29'},
#  {'text': 'November 2016, issue 28',
#   'href': '/journal/216/volumes-and-issues/408-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-28'},
#  {'text': 'November 2016, issue 27',
#   'href': '/journal/216/volumes-and-issues/408-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-27'},
#  {'text': 'October 2016, issue 26',
#   'href': '/journal/216/volumes-and-issues/408-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-26'},
#  {'text': 'October 2016, issue 25',
#   'href': '/journal/216/volumes-and-issues/408-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-25'},
#  {'text': 'September 2016, issue 24',
#   'href': '/journal/216/volumes-and-issues/408-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-24'},
#  {'text': 'September 2016, issue 23',
#   'href': '/journal/216/volumes-and-issues/408-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-23'},
#  {'text': 'September 2016, issue 22',
#   'href': '/journal/216/volumes-and-issues/408-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-22'},
#  {'text': 'August 2016, issue 21',
#   'href': '/journal/216/volumes-and-issues/408-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-21'},
#  {'text': 'August 2016, issue 20',
#   'href': '/journal/216/volumes-and-issues/408-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-20'},
#  {'text': 'July 2016, issue 19',
#   'href': '/journal/216/volumes-and-issues/408-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-19'},
#  {'text': 'July 2016, issue 18',
#   'href': '/journal/216/volumes-and-issues/408-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-18'},
#  {'text': 'July 2016, issue 17',
#   'href': '/journal/216/volumes-and-issues/408-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-17'},
#  {'text': 'June 2016, issue 16',
#   'href': '/journal/216/volumes-and-issues/408-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-16'},
#  {'text': 'June 2016, issue 15',
#   'href': '/journal/216/volumes-and-issues/408-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-15'},
#  {'text': 'May 2016, issue 14',
#   'href': '/journal/216/volumes-and-issues/408-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-14'},
#  {'text': 'May 2016, issue 13',
#   'href': '/journal/216/volumes-and-issues/408-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-13'},
#  {'text': 'May 2016, issue 12',
#   'href': '/journal/216/volumes-and-issues/408-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-12'},
#  {'text': 'April 2016, issue 11',
#   'href': '/journal/216/volumes-and-issues/408-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-11'},
#  {'text': 'April 2016, issue 10',
#   'href': '/journal/216/volumes-and-issues/408-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-10'},
#  {'text': 'March 2016, issue 9',
#   'href': '/journal/216/volumes-and-issues/408-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-9'},
#  {'text': 'March 2016, issue 8',
#   'href': '/journal/216/volumes-and-issues/408-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-8'},
#  {'text': 'March 2016, issue 7',
#   'href': '/journal/216/volumes-and-issues/408-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-7'},
#  {'text': 'February 2016, issue 6',
#   'href': '/journal/216/volumes-and-issues/408-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-6'},
#  {'text': 'February 2016, issue 5',
#   'href': '/journal/216/volumes-and-issues/408-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-5'},
#  {'text': 'February 2016, issue 4',
#   'href': '/journal/216/volumes-and-issues/408-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-4'},
#  {'text': 'January 2016, issue 3',
#   'href': '/journal/216/volumes-and-issues/408-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-3'},
#  {'text': 'January 2016, issue 2',
#   'href': '/journal/216/volumes-and-issues/408-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-2'},
#  {'text': 'January 2016, issue 1',
#   'href': '/journal/216/volumes-and-issues/408-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/408-1'},
#  {'text': 'December 2015, issue 30',
#   'href': '/journal/216/volumes-and-issues/407-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-30'},
#  {'text': 'November 2015, issue 29',
#   'href': '/journal/216/volumes-and-issues/407-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-29'},
#  {'text': 'November 2015, issue 28',
#   'href': '/journal/216/volumes-and-issues/407-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-28'},
#  {'text': 'November 2015, issue 27',
#   'href': '/journal/216/volumes-and-issues/407-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-27'},
#  {'text': 'October 2015, issue 26',
#   'href': '/journal/216/volumes-and-issues/407-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-26'},
#  {'text': 'October 2015, issue 25',
#   'href': '/journal/216/volumes-and-issues/407-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-25'},
#  {'text': 'September 2015, issue 24',
#   'href': '/journal/216/volumes-and-issues/407-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-24'},
#  {'text': 'September 2015, issue 23',
#   'href': '/journal/216/volumes-and-issues/407-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-23'},
#  {'text': 'September 2015, issue 22',
#   'href': '/journal/216/volumes-and-issues/407-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-22'},
#  {'text': 'August 2015, issue 21',
#   'href': '/journal/216/volumes-and-issues/407-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-21'},
#  {'text': 'August 2015, issue 20',
#   'href': '/journal/216/volumes-and-issues/407-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-20'},
#  {'text': 'July 2015, issue 19',
#   'href': '/journal/216/volumes-and-issues/407-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-19'},
#  {'text': 'July 2015, issue 18',
#   'href': '/journal/216/volumes-and-issues/407-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-18'},
#  {'text': 'July 2015, issue 17',
#   'href': '/journal/216/volumes-and-issues/407-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-17'},
#  {'text': 'June 2015, issue 16',
#   'href': '/journal/216/volumes-and-issues/407-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-16'},
#  {'text': 'June 2015, issue 15',
#   'href': '/journal/216/volumes-and-issues/407-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-15'},
#  {'text': 'May 2015, issue 14',
#   'href': '/journal/216/volumes-and-issues/407-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-14'},
#  {'text': 'May 2015, issue 13',
#   'href': '/journal/216/volumes-and-issues/407-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-13'},
#  {'text': 'May 2015, issue 12',
#   'href': '/journal/216/volumes-and-issues/407-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-12'},
#  {'text': 'April 2015, issue 11',
#   'href': '/journal/216/volumes-and-issues/407-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-11'},
#  {'text': 'April 2015, issue 10',
#   'href': '/journal/216/volumes-and-issues/407-10',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-10'},
#  {'text': 'March 2015, issue 9',
#   'href': '/journal/216/volumes-and-issues/407-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-9'},
#  {'text': 'March 2015, issue 8',
#   'href': '/journal/216/volumes-and-issues/407-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-8'},
#  {'text': 'March 2015, issue 7',
#   'href': '/journal/216/volumes-and-issues/407-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-7'},
#  {'text': 'February 2015, issue 6',
#   'href': '/journal/216/volumes-and-issues/407-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-6'},
#  {'text': 'February 2015, issue 5',
#   'href': '/journal/216/volumes-and-issues/407-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-5'},
#  {'text': 'February 2015, issue 4',
#   'href': '/journal/216/volumes-and-issues/407-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-4'},
#  {'text': 'January 2015, issue 3',
#   'href': '/journal/216/volumes-and-issues/407-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-3'},
#  {'text': 'January 2015, issue 2',
#   'href': '/journal/216/volumes-and-issues/407-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-2'},
#  {'text': 'January 2015, issue 1',
#   'href': '/journal/216/volumes-and-issues/407-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/407-1'},
#  {'text': 'December 2014, issue 30',
#   'href': '/journal/216/volumes-and-issues/406-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-30'},
#  {'text': 'November 2014, issue 29',
#   'href': '/journal/216/volumes-and-issues/406-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-29'},
#  {'text': 'November 2014, issue 28',
#   'href': '/journal/216/volumes-and-issues/406-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-28'},
#  {'text': 'November 2014, issue 27',
#   'href': '/journal/216/volumes-and-issues/406-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-27'},
#  {'text': 'October 2014, issue 26',
#   'href': '/journal/216/volumes-and-issues/406-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-26'},
#  {'text': 'October 2014, issue 25',
#   'href': '/journal/216/volumes-and-issues/406-25',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-25'},
#  {'text': 'September 2014, issue 24',
#   'href': '/journal/216/volumes-and-issues/406-24',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-24'},
#  {'text': 'September 2014, issue 23',
#   'href': '/journal/216/volumes-and-issues/406-23',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-23'},
#  {'text': 'September 2014, issue 22',
#   'href': '/journal/216/volumes-and-issues/406-22',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-22'},
#  {'text': 'August 2014, issue 21',
#   'href': '/journal/216/volumes-and-issues/406-21',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-21'},
#  {'text': 'August 2014, issue 20',
#   'href': '/journal/216/volumes-and-issues/406-20',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-20'},
#  {'text': 'July 2014, issue 19',
#   'href': '/journal/216/volumes-and-issues/406-19',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-19'},
#  {'text': 'July 2014, issue 18',
#   'href': '/journal/216/volumes-and-issues/406-18',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-18'},
#  {'text': 'July 2014, issue 17',
#   'href': '/journal/216/volumes-and-issues/406-17',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-17'},
#  {'text': 'June 2014, issue 16',
#   'href': '/journal/216/volumes-and-issues/406-16',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-16'},
#  {'text': 'June 2014, issue 15',
#   'href': '/journal/216/volumes-and-issues/406-15',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-15'},
#  {'text': 'May 2014, issue 14',
#   'href': '/journal/216/volumes-and-issues/406-14',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-14'},
#  {'text': 'May 2014, issue 13',
#   'href': '/journal/216/volumes-and-issues/406-13',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-13'},
#  {'text': 'May 2014, issue 12',
#   'href': '/journal/216/volumes-and-issues/406-12',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-12'},
#  {'text': 'April 2014, issue 11',
#   'href': '/journal/216/volumes-and-issues/406-11',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-11'},
#  {'text': 'April 2014, issue 9-10',
#   'href': '/journal/216/volumes-and-issues/406-9',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-9'},
#  {'text': 'March 2014, issue 8',
#   'href': '/journal/216/volumes-and-issues/406-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-8'},
#  {'text': 'March 2014, issue 7',
#   'href': '/journal/216/volumes-and-issues/406-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-7'},
#  {'text': 'February 2014, issue 6',
#   'href': '/journal/216/volumes-and-issues/406-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-6'},
#  {'text': 'February 2014, issue 5',
#   'href': '/journal/216/volumes-and-issues/406-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-5'},
#  {'text': 'February 2014, issue 4',
#   'href': '/journal/216/volumes-and-issues/406-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-4'},
#  {'text': 'January 2014, issue 3',
#   'href': '/journal/216/volumes-and-issues/406-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-3'},
#  {'text': 'January 2014, issue 2',
#   'href': '/journal/216/volumes-and-issues/406-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-2'},
#  {'text': 'January 2014, issue 1',
#   'href': '/journal/216/volumes-and-issues/406-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/406-1'},
#  {'text': 'December 2013, issue 30',
#   'href': '/journal/216/volumes-and-issues/405-30',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/405-30'},
#  {'text': 'November 2013, issue 29',
#   'href': '/journal/216/volumes-and-issues/405-29',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/405-29'},
#  {'text': 'November 2013, issue 28',
#   'href': '/journal/216/volumes-and-issues/405-28',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/405-28'},
#  {'text': 'November 2013, issue 27',
#   'href': '/journal/216/volumes-and-issues/405-27',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/405-27'},
#  {'text': 'October 2013, issue 26',
#   'href': '/journal/216/volumes-and-issues/405-26',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/405-26'},
# ...
#  {'text': 'September 2004, issue 1',
#   'href': '/journal/216/volumes-and-issues/380-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/380-1'},
#  {'text': 'August 2004, issue 7-8',
#   'href': '/journal/216/volumes-and-issues/379-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-7'},
#  {'text': 'July 2004, issue 5-6',
#   'href': '/journal/216/volumes-and-issues/379-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-5'},
#  {'text': 'June 2004, issue 4',
#   'href': '/journal/216/volumes-and-issues/379-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-4'},
#  {'text': 'June 2004, issue 3',
#   'href': '/journal/216/volumes-and-issues/379-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-3'},
#  {'text': 'May 2004, issue 2',
#   'href': '/journal/216/volumes-and-issues/379-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-2'},
#  {'text': 'May 2004, issue 1',
#   'href': '/journal/216/volumes-and-issues/379-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/379-1'},
#  {'text': 'April 2004, issue 8',
#   'href': '/journal/216/volumes-and-issues/378-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-8'},
#  {'text': 'April 2004, issue 7',
#   'href': '/journal/216/volumes-and-issues/378-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-7'},
#  {'text': 'March 2004, issue 6',
#   'href': '/journal/216/volumes-and-issues/378-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-6'},
#  {'text': 'March 2004, issue 5',
#   'href': '/journal/216/volumes-and-issues/378-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-5'},
#  {'text': 'February 2004, issue 4',
#   'href': '/journal/216/volumes-and-issues/378-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-4'},
#  {'text': 'February 2004, issue 3',
#   'href': '/journal/216/volumes-and-issues/378-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-3'},
#  {'text': 'January 2004, issue 2',
#   'href': '/journal/216/volumes-and-issues/378-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-2'},
#  {'text': 'January 2004, issue 1',
#   'href': '/journal/216/volumes-and-issues/378-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/378-1'},
#  {'text': 'December 2003, issue 7-8',
#   'href': '/journal/216/volumes-and-issues/377-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-7'},
#  {'text': 'November 2003, issue 6',
#   'href': '/journal/216/volumes-and-issues/377-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-6'},
#  {'text': 'November 2003, issue 5',
#   'href': '/journal/216/volumes-and-issues/377-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-5'},
#  {'text': 'October 2003, issue 4',
#   'href': '/journal/216/volumes-and-issues/377-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-4'},
#  {'text': 'October 2003, issue 3',
#   'href': '/journal/216/volumes-and-issues/377-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-3'},
#  {'text': 'September 2003, issue 2',
#   'href': '/journal/216/volumes-and-issues/377-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-2'},
#  {'text': 'September 2003, issue 1',
#   'href': '/journal/216/volumes-and-issues/377-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/377-1'},
#  {'text': 'August 2003, issue 8',
#   'href': '/journal/216/volumes-and-issues/376-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-8'},
#  {'text': 'August 2003, issue 7',
#   'href': '/journal/216/volumes-and-issues/376-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-7'},
#  {'text': 'July 2003, issue 6',
#   'href': '/journal/216/volumes-and-issues/376-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-6'},
#  {'text': 'July 2003, issue 5',
#   'href': '/journal/216/volumes-and-issues/376-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-5'},
#  {'text': 'June 2003, issue 4',
#   'href': '/journal/216/volumes-and-issues/376-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-4'},
#  {'text': 'June 2003, issue 3',
#   'href': '/journal/216/volumes-and-issues/376-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-3'},
#  {'text': 'May 2003, issue 2',
#   'href': '/journal/216/volumes-and-issues/376-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-2'},
#  {'text': 'May 2003, issue 1',
#   'href': '/journal/216/volumes-and-issues/376-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/376-1'},
#  {'text': 'April 2003, issue 8',
#   'href': '/journal/216/volumes-and-issues/375-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-8'},
#  {'text': 'April 2003, issue 7',
#   'href': '/journal/216/volumes-and-issues/375-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-7'},
#  {'text': 'March 2003, issue 6',
#   'href': '/journal/216/volumes-and-issues/375-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-6'},
#  {'text': 'March 2003, issue 5',
#   'href': '/journal/216/volumes-and-issues/375-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-5'},
#  {'text': 'February 2003, issue 4',
#   'href': '/journal/216/volumes-and-issues/375-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-4'},
#  {'text': 'February 2003, issue 3',
#   'href': '/journal/216/volumes-and-issues/375-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-3'},
#  {'text': 'January 2003, issue 2',
#   'href': '/journal/216/volumes-and-issues/375-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-2'},
#  {'text': 'January 2003, issue 1',
#   'href': '/journal/216/volumes-and-issues/375-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/375-1'},
#  {'text': 'December 2002, issue 7-8',
#   'href': '/journal/216/volumes-and-issues/374-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-7'},
#  {'text': 'November 2002, issue 6',
#   'href': '/journal/216/volumes-and-issues/374-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-6'},
#  {'text': 'November 2002, issue 5',
#   'href': '/journal/216/volumes-and-issues/374-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-5'},
#  {'text': 'October 2002, issue 4',
#   'href': '/journal/216/volumes-and-issues/374-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-4'},
#  {'text': 'October 2002, issue 3',
#   'href': '/journal/216/volumes-and-issues/374-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-3'},
#  {'text': 'September 2002, issue 2',
#   'href': '/journal/216/volumes-and-issues/374-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-2'},
#  {'text': 'September 2002, issue 1',
#   'href': '/journal/216/volumes-and-issues/374-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/374-1'},
#  {'text': 'August 2002, issue 8',
#   'href': '/journal/216/volumes-and-issues/373-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-8'},
#  {'text': 'August 2002, issue 7',
#   'href': '/journal/216/volumes-and-issues/373-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-7'},
#  {'text': 'July 2002, issue 6',
#   'href': '/journal/216/volumes-and-issues/373-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-6'},
#  {'text': 'July 2002, issue 4-5',
#   'href': '/journal/216/volumes-and-issues/373-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-4'},
#  {'text': 'June 2002, issue 3',
#   'href': '/journal/216/volumes-and-issues/373-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-3'},
#  {'text': 'May 2002, issue 1-2',
#   'href': '/journal/216/volumes-and-issues/373-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/373-1'},
#  {'text': 'April 2002, issue 7-8',
#   'href': '/journal/216/volumes-and-issues/372-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-7'},
#  {'text': 'March 2002, issue 5-6',
#   'href': '/journal/216/volumes-and-issues/372-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-5'},
#  {'text': 'February 2002, issue 4',
#   'href': '/journal/216/volumes-and-issues/372-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-4'},
#  {'text': 'February 2002, issue 3',
#   'href': '/journal/216/volumes-and-issues/372-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-3'},
#  {'text': 'January 2002, issue 2',
#   'href': '/journal/216/volumes-and-issues/372-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-2'},
#  {'text': 'January 2002, issue 1',
#   'href': '/journal/216/volumes-and-issues/372-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/372-1'},
#  {'text': 'December 2001, issue 8',
#   'href': '/journal/216/volumes-and-issues/371-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-8'},
#  {'text': 'December 2001, issue 7',
#   'href': '/journal/216/volumes-and-issues/371-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-7'},
#  {'text': 'November 2001, issue 6',
#   'href': '/journal/216/volumes-and-issues/371-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-6'},
#  {'text': 'November 2001, issue 5',
#   'href': '/journal/216/volumes-and-issues/371-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-5'},
#  {'text': 'October 2001, issue 4',
#   'href': '/journal/216/volumes-and-issues/371-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-4'},
#  {'text': 'October 2001, issue 3',
#   'href': '/journal/216/volumes-and-issues/371-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-3'},
#  {'text': 'September 2001, issue 2',
#   'href': '/journal/216/volumes-and-issues/371-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-2'},
#  {'text': 'September 2001, issue 1',
#   'href': '/journal/216/volumes-and-issues/371-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/371-1'},
#  {'text': 'August 2001, issue 8',
#   'href': '/journal/216/volumes-and-issues/370-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-8'},
#  {'text': 'August 2001, issue 7',
#   'href': '/journal/216/volumes-and-issues/370-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-7'},
#  {'text': 'July 2001, issue 6',
#   'href': '/journal/216/volumes-and-issues/370-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-6'},
#  {'text': 'July 2001, issue 5',
#   'href': '/journal/216/volumes-and-issues/370-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-5'},
#  {'text': 'June 2001, issue 4',
#   'href': '/journal/216/volumes-and-issues/370-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-4'},
#  {'text': 'June 2001, issue 2-3',
#   'href': '/journal/216/volumes-and-issues/370-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-2'},
#  {'text': 'May 2001, issue 1',
#   'href': '/journal/216/volumes-and-issues/370-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/370-1'},
#  {'text': 'April 2001, issue 7-8',
#   'href': '/journal/216/volumes-and-issues/369-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-7'},
#  {'text': 'March 2001, issue 6',
#   'href': '/journal/216/volumes-and-issues/369-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-6'},
#  {'text': 'March 2001, issue 5',
#   'href': '/journal/216/volumes-and-issues/369-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-5'},
#  {'text': 'February 2001, issue 3-4',
#   'href': '/journal/216/volumes-and-issues/369-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-3'},
#  {'text': 'January 2001, issue 2',
#   'href': '/journal/216/volumes-and-issues/369-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-2'},
#  {'text': 'January 2001, issue 1',
#   'href': '/journal/216/volumes-and-issues/369-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/369-1'},
#  {'text': 'December 2000, issue 8',
#   'href': '/journal/216/volumes-and-issues/368-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-8'},
#  {'text': 'November 2000, issue 7',
#   'href': '/journal/216/volumes-and-issues/368-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-7'},
#  {'text': 'November 2000, issue 6',
#   'href': '/journal/216/volumes-and-issues/368-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-6'},
#  {'text': 'October 2000, issue 5',
#   'href': '/journal/216/volumes-and-issues/368-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-5'},
#  {'text': 'October 2000, issue 4',
#   'href': '/journal/216/volumes-and-issues/368-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-4'},
#  {'text': 'September 2000, issue 2-3',
#   'href': '/journal/216/volumes-and-issues/368-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-2'},
#  {'text': 'August 2000, issue 1',
#   'href': '/journal/216/volumes-and-issues/368-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/368-1'},
#  {'text': 'August 2000, issue 8',
#   'href': '/journal/216/volumes-and-issues/367-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-8'},
#  {'text': 'July 2000, issue 7',
#   'href': '/journal/216/volumes-and-issues/367-7',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-7'},
#  {'text': 'July 2000, issue 6',
#   'href': '/journal/216/volumes-and-issues/367-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-6'},
#  {'text': 'June 2000, issue 5',
#   'href': '/journal/216/volumes-and-issues/367-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-5'},
#  {'text': 'June 2000, issue 4',
#   'href': '/journal/216/volumes-and-issues/367-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-4'},
#  {'text': 'May 2000, issue 3',
#   'href': '/journal/216/volumes-and-issues/367-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-3'},
#  {'text': 'May 2000, issue 2',
#   'href': '/journal/216/volumes-and-issues/367-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-2'},
#  {'text': 'April 2000, issue 1',
#   'href': '/journal/216/volumes-and-issues/367-1',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/367-1'},
#  {'text': 'April 2000, issue 8',
#   'href': '/journal/216/volumes-and-issues/366-8',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-8'},
#  {'text': 'March 2000, issue 6-7',
#   'href': '/journal/216/volumes-and-issues/366-6',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-6'},
#  {'text': 'March 2000, issue 5',
#   'href': '/journal/216/volumes-and-issues/366-5',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-5'},
#  {'text': 'February 2000, issue 4',
#   'href': '/journal/216/volumes-and-issues/366-4',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-4'},
#  {'text': 'February 2000, issue 3',
#   'href': '/journal/216/volumes-and-issues/366-3',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-3'},
#  {'text': 'January 2000, issue 2',
#   'href': '/journal/216/volumes-and-issues/366-2',
#   'url': 'https://link.springer.com/journal/216/volumes-and-issues/366-2'}]

# %%
#data export
if not os.path.exists('data'):
    os.makedirs('data')
pd.DataFrame(high_catalogue).to_csv('data/high_catalogue.csv', index = False)

# %%
#sample issues
low_catalogue[10]['url']
# Out:
# 'https://link.springer.com/journal/10809/volumes-and-issues/77-12'

# %%
#manual test
test_url = low_catalogue[0]['url']
test_res = requests.get(test_url)
test_soup = BeautifulSoup(test_res.content, 'html.parser')
test_a_elements = test_soup.select('li.c-list-group__item a')

# %%
paper_url = 'https://link.springer.com/article/10.1134/S106193482209009X'
paper_res = requests.get(paper_url)
paper_soup = BeautifulSoup(paper_res.content, 'html.parser')
abstract_section = paper_soup.find('div', {'id': 'Abs1-content'})
content_type_section = paper_soup.find('li', {'data-test': 'article-category'})
published_date_section = paper_soup.find('time', 'datetime')

# %%
abstract_text = abstract_section.find('p').text.replace("\xa0", " ").strip()
abstract_text
# Out:
# 'The paper presents one of lines of scientific inquiry of the Department of Analytical Chemistry and Chemical Ecology of Saratov University – establishing a relationship of the physicochemical, analytical, and other properties, reactivity, and biological activity of substances with the energetics, spatial and electronic structure, molecular descriptors of reactants, transition states, intermediates, nanoclusters in the ground and excited states, generalization of views on the mechanisms and regioselectivity of reactions, study of the effects of electrostatic and hydrophobic factors, and medium on various properties and the course of chemical processes; quantum-chemical study of the electronic effects of atomic groups in molecules, hydrogen bonding; revealing the nature of interactions between unbound atoms in small and/or strained molecular systems, in small and medium quasicycles; elucidation (on the basis of NBO analysis of hybridization) of the question of the differential participation of lone electron pairs of heteroatoms in reactions with electrophilic agents; prediction of a possibility of formation and the stability of ionic associates, their ability to extraction; consideration of stabilization factors for ion associates (including those significant for analytical chemistry) and systems with open electron shells (including analytical reagents); revelation of quantitative structure–property relationships; development of the theory of the structure and action of analytical reagents; molecular modeling of analytically significant biospecific protein–ligand interactions.'

# %%
content_type_section = paper_soup.find('li', {'data-test': 'article-category'})
published_date_section = paper_soup.find('a', {'data-track': 'click', 'data-track-action': 'publication date'})
content_type_section = paper_soup.find('li', {'data-test': 'article-category'})
published_date_section = paper_soup.find('a', {'data-track': 'click', 
                                               'data-track-action': 'publication date'})

# %%
#set up function to call data from preloaded catalogue list with start stop range to break up scraping
def datagrab(catalogues, start=0, stop=100):
    #set up list for paper_data dump
    journal_data = []

    #loop through catalogues list to get each url
    for n in tqdm(range(start, stop)):
        issue_url = catalogues[n]['url']
        issue_res = requests.get(issue_url)

        #instantiate and set blank list
        soup = BeautifulSoup(issue_res.content, 'html.parser')

        #finding a & meta elements to extract the href (as url), abstract_section, content_type_section, published_date_section
        a_elements = soup.select('li.c-list-group__item a')

        # Loop through the <a> elements and extract the href and text data
        for i, a in enumerate(a_elements):
            paper_url = a['href']
            paper_res = requests.get(paper_url)
            paper_soup = BeautifulSoup(paper_res.content, 'html.parser')
            abstract_section = paper_soup.find('div', {'id': 'Abs1-content'})
            content_type_section = paper_soup.find('li', {'data-test': 'article-category'})
            published_date_section = paper_soup.find('a', {'data-track': 'click', 
                                                           'data-track-action': 'publication date'})
            #some pages does not have abstract. content type etc or built differently, try-except needed to prevent break.
            try:                #strip to remove whitespaces
                abstract_text = abstract_section.find('p').text.replace("\xa0", " ").strip()
                content_type_text = content_type_section.text.strip()
                published_date_text = published_date_section.find('time').text.strip()
                
                #combine all data into a dictionary and throw back to list.
                paper_data = {'title' : a_elements[i].text.strip(),    
                             'issue' : catalogues[n]['text'],
                             'issue_href' : catalogues[n]['href'],
                             'url': a['href'],
                             'content_type' : content_type_text,
                             'publish_date' : published_date_text,
                             'abstract' : abstract_text
                            }
                journal_data.append(paper_data)
#optionl cooldown timer per paper to lower hashrate and prevent kick out.
                cooldown_time = random.uniform(0.1, 2.5)
                time.sleep(cooldown_time)
            except:
              continue
#optional cooldown per issue
        cooldown_time = random.uniform(0.1, 10.5)
        time.sleep(cooldown_time)
    #combine into df to return for export later
    journal_df = pd.DataFrame(journal_data)
    return journal_df

# %% [markdown]
# ## Scrape & save
# - Load back previously generated catalogue to scrape in sections to prevent blocks or other issues.
# - Concatenate data
# - Export

# %%
#import back in catalogue
high_catalogue_df = pd.read_csv('data/high_catalogue.csv')
high_catalogue = high_catalogue_df.to_dict('records')

low_catalogue_df = pd.read_csv('data/low_catalogue.csv')
low_catalogue = low_catalogue_df.to_dict('records')

# %%
#download high_HI catalogue
high_papers_df = datagrab(high_catalogue, 0, 2)  #set to 2 for demonstration purpose only
high_papers_df
# Out:
# 100%|███████████████████████████████████████████| 2/2 [03:25<00:00, 102.96s/it]
#                                                 title  \
# 0   Rules for mass spectrometry applications in th...
# 1   Strategies for automating analytical and bioan...
# 2   The role of comprehensive two-dimensional gas ...
# 3   Confocal micro X-ray fluorescence analysis for...
# 4   Advances in testing for sample manipulation in...
# 5   Advances in testing for sample manipulation in...
# 6   Integrated microscale immiscible phase extract...
# 7   Immunomagnetic separation coupled with flow cy...
# 8   Tailored extraction and ion mobility-mass spec...
# 9   Detection, chemical analysis, and pharmacologi...
# 10  Optofluidic force induction as a process analy...
# 11  Screening bisphenols in complex samples via a ...
# 12  Responsive Janus droplets as modular sensory l...
# 13  Portable biosensor-based oral pathogenic bacte...
# 14  Raman mapping for determination of TiO2 in dif...
# 15  Complementary methods for structural assignmen...
# 16  Enzyme-targeted near-infrared fluorescent prob...
# 17  A numerical study on microfluidic devices to m...
# 18  Sensitive and discriminative detection of cyst...
# 19  A comparison of four liquid chromatography–mas...
# 20  Plasmon-enhanced fluorescence for ellagic acid...
# 21  A sensitive electrochemical aptasensor for zea...
# 22  Dynamic in situ growth of bonded-phase silica ...
# 23  A novel dual-channel immunochromatographic str...
# 24  A selective fluorescent turn-on probe for imag...
# 25  Fast profiling of primary, secondary, conjugat...
# 26  Rapid detection of Shiga-toxin-producing Esche...
# 27  Polypyrrole/carbon dot nanocomposite as an ele...
# 28  Development and validation of an eco-compatibl...
# 29  Molecularly imprinted thermosensitive probe ba...
# 30  Sample pooling and incurred samples improve an...
# 31  Synthesis of a novel isotopically labelled sta...
#
#                        issue                              issue_href  \
# 0   September 2023, issue 21  /journal/216/volumes-and-issues/415-21
#
# 10   01 July 2023  Manufacturers of nanoparticle-based products r...
# 11   17 July 2023  The Arxula yeast bisphenol screen (A-YBS) util...
# 12   14 July 2023  The field of biosensor development is fueled b...
# 13   30 June 2023  Detection of oral pathogens is essential in th...
# 14   13 July 2023  Titanium dioxide is a food additive commonly u...
# 15   15 July 2023  Non-target screening with LC/IMS/HRMS is incre...
# 16   12 July 2023  Pesticide residues significantly affect food s...
# 17   29 June 2023  Determining the physical and chemical properti...
# 18   15 June 2023  Cysteine (Cys) is a significant biological mer...
# 19   11 July 2023  Targeted biomonitoring studies quantifying the...
# 20   21 June 2023  Ellagic acid (EA), as a natural polyphenolic a...
# 21   16 June 2023  Traditional methods for detecting antibiotic a...
# 22   23 June 2023  Silica nanospheres (SNS) were grown on the inn...
# 23   15 July 2023  Due to universal contamination and synergistic...
# 24   17 June 2023  Fluorescent turn-on probes have been extensive...
# 25   20 June 2023  Bile acids (BAs) are a complex class of metabo...
# 26   27 June 2023  Contamination by Escherichia coli O157:H7 is c...
# 27   04 July 2023  Liquid biopsy analysis represents a suitable a...
# 28   14 June 2023  Cu2+ are ubiquitous ions in the ecosystem and ...
# 29   21 June 2023  A thermal-sensitive molecularly imprinted opto...
# 30   22 June 2023  Lipophilic marine biotoxins (LMBs) are one of ...
# 31   13 June 2023  γ-Nonalactone is a linear aliphatic lactone ub...

# %%
#download low_HI catalogue
low_papers_df = datagrab(low_catalogue, 0, 2)    #set to 2 for demonstration purpose only/
low_papers_df.head()
# Out:
# 100%|████████████████████████████████████████████| 2/2 [02:15<00:00, 67.57s/it]
#                                                 title                 issue  \
# 0   Proteins: Templates and Matrices in Molecular ...  August 2023, issue 8
# 1   Determination and Quantification of Cetirizine...  August 2023, issue 8
# 2   Experience of the Determination of Fluorine in...  August 2023, issue 8
# 3   A Green-Solvent Based Dispersive Liquid–Liquid...  August 2023, issue 8
# 4   Adaptive Calibration in Electrothermal Atomic ...  August 2023, issue 8
# 5   Effect of Organic Additives on the Intensity o...  August 2023, issue 8
# 6   Characterization and Comparison of Automobile ...  August 2023, issue 8
# 7   Using Highly Sensitive Piezo Sensors in an Ope...  August 2023, issue 8
# 8   Development of a Bioanalytical Method for the ...  August 2023, issue 8
# 9   Profiling Detection and Validation of Six Sart...  August 2023, issue 8
# 10  Approbation of a Procedure for Determining the...  August 2023, issue 8
# 11  Development and Optimization of an Algorithm f...  August 2023, issue 8
# 12  Facile Synthesis of a Novel Zr/Fe3O4/GO Nanoco...  August 2023, issue 8
# 13  Biohybrid Technology for the Detection of Ultr...  August 2023, issue 8
# 14  Estimation of Organic Opacifier in Water-Based...  August 2023, issue 8
# 15  Systematic Errors in the Results of Quantitati...  August 2023, issue 8
# 16        Origins and Formation of Ion Chromatography  August 2023, issue 8
# 17  Capillary Electrophoresis in Assessing the Qua...    July 2023, issue 7
# 18  Spectrophotometric Investigation and Computati...    July 2023, issue 7
# 19  New Schiff Base-Linked Arylazopyrazoles as Rea...    July 2023, issue 7
# 20  Validated Spectrophotometric Methods for the R...    July 2023, issue 7
# 25  https://link.springer.com/article/10.1134/S106...
# 26  https://link.springer.com/article/10.1134/S106...
# 27  https://link.springer.com/article/10.1134/S106...
#
#                        content_type    publish_date  \
# 0                           REVIEWS  02 August 2023
# 1                          ARTICLES  02 August 2023
# 2                          ARTICLES  02 August 2023
# 3                          ARTICLES  02 August 2023
# 4                          ARTICLES  02 August 2023
# 5                          ARTICLES  02 August 2023
# 6                          ARTICLES  02 August 2023
# 7                          ARTICLES  02 August 2023
# 8                          ARTICLES  02 August 2023
# 9                          ARTICLES  02 August 2023
# 10                         ARTICLES  02 August 2023
# 11                         ARTICLES  02 August 2023
# 12                         ARTICLES  02 August 2023
# 13                         ARTICLES  02 August 2023
# 14                         ARTICLES  02 August 2023
# 15                      DISCUSSIONS  02 August 2023
# 16  HISTORY OF ANALYTICAL CHEMISTRY  02 August 2023
# 17                          REVIEWS    18 July 2023
# 18                         ARTICLES    18 July 2023
# 19                         ARTICLES    18 July 2023
# 20                         ARTICLES    18 July 2023
# 21                         ARTICLES    18 July 2023
# 22                         ARTICLES    18 July 2023
# 23                         ARTICLES    18 July 2023
# 24                         ARTICLES    18 July 2023
# 25                         ARTICLES    18 July 2023
# 26                         ARTICLES    18 July 2023
# 27                         ARTICLES    18 July 2023
#
#                                              abstract
# 0   This review considers the issues of molecular ...
# 1   A simple, fast, sensitive, cost-effective, and...
# 2   The main fluorine-concentrating minerals in ro...
# 3   This research presents the use of deep eutecti...
# 4   A method is developed for determining concentr...
# 5   The effect of the nature and concentration of ...
# 6   Automotive paint flakes are significant for th...
# 7   A single sensor with a piezoelectric quartz tr...
# 8   Since fungal infections are on the rise and wi...
# 9   Six sartan substances including telmisartan, l...
# 10  The ratio of stable carbon isotopes can give i...
# 11  This paper addresses the problem of estimation...
# 12  A ZrNPs/Fe3O4/GO nanocomposite was successfull...
# 13  The technology is based on recording the focal...
# 14  Hollow sphere polymeric pigments prepared from...
# 15  It is noticed that the conventional interpreta...
# 16  The origins and ways of formation of ion chrom...
# 17  This review is dedicated to the application of...
# 18  A new binary liquid-liquid extraction techniqu...
# 19  A novel class of reagents (L1–3) containing ar...
# 20  Two simple, rapid, accurate, and precise spect...
# 21  A reliable and environmental analytical method...
# 22  An environmentally friendly, simple and rapid ...
# 23  A method of dispersive liquid–liquid microextr...
# 24  For the first time, an UPLC-QTOF-MS method was...
# 25  Adsorbents based on various substrates—silica ...
# 26  A voltammetric sensor was developed based on a...
# 27  High-current cathodic pulses on an aluminum el...

# %%
high_papers_df.head()
# Out:
#                                                 title  \
# 0   Rules for mass spectrometry applications in th...
# 1   Strategies for automating analytical and bioan...
# 2   The role of comprehensive two-dimensional gas ...
# 3   Confocal micro X-ray fluorescence analysis for...
# 4   Advances in testing for sample manipulation in...
# 5   Advances in testing for sample manipulation in...
# 6   Integrated microscale immiscible phase extract...
# 7   Immunomagnetic separation coupled with flow cy...
# 8   Tailored extraction and ion mobility-mass spec...
# 9   Detection, chemical analysis, and pharmacologi...
# 10  Optofluidic force induction as a process analy...
# 11  Screening bisphenols in complex samples via a ...
# 28  https://link.springer.com/article/10.1007/s002...      Research Paper
# 29  https://link.springer.com/article/10.1007/s002...      Research Paper
# 30  https://link.springer.com/article/10.1007/s002...      Research Paper
# 31  https://link.springer.com/article/10.1007/s002...      Research Paper
#
#      publish_date                                           abstract
# 0   25 March 2023  MS-based analytical methods now play an import...
# 1     13 May 2023  Analytical measurement methods are used in dif...
# 2     06 May 2023  Mineral oil hydrocarbons (MOH) contain a wide ...
# 3    24 July 2023  Confocal micro X-ray fluorescence (CMXRF) spec...
# 4     05 May 2023  In many countries, adherence testing is used t...
# 5   28 April 2023  As a continuation of part A, focusing on advan...
# 6     18 May 2023  Gonorrhea is the second most common sexually t...
# 7     18 May 2023  Legionella pneumophila are pathogenic bacteria...
# 8    22 June 2023  Climate change directs the focus in biotechnol...
# 9     13 May 2023  The emergence of structurally diverse new synt...
# 10   01 July 2023  Manufacturers of nanoparticle-based products r...
# 11   17 July 2023  The Arxula yeast bisphenol screen (A-YBS) util...
# 12   14 July 2023  The field of biosensor development is fueled b...
# 13   30 June 2023  Detection of oral pathogens is essential in th...
# 14   13 July 2023  Titanium dioxide is a food additive commonly u...
# 15   15 July 2023  Non-target screening with LC/IMS/HRMS is incre...
# 16   12 July 2023  Pesticide residues significantly affect food s...
# 17   29 June 2023  Determining the physical and chemical properti...
# 18   15 June 2023  Cysteine (Cys) is a significant biological mer...
# 19   11 July 2023  Targeted biomonitoring studies quantifying the...
# 20   21 June 2023  Ellagic acid (EA), as a natural polyphenolic a...
# 21   16 June 2023  Traditional methods for detecting antibiotic a...
# 22   23 June 2023  Silica nanospheres (SNS) were grown on the inn...
# 23   15 July 2023  Due to universal contamination and synergistic...
# 24   17 June 2023  Fluorescent turn-on probes have been extensive...
# 25   20 June 2023  Bile acids (BAs) are a complex class of metabo...
# 26   27 June 2023  Contamination by Escherichia coli O157:H7 is c...
# 27   04 July 2023  Liquid biopsy analysis represents a suitable a...
# 28   14 June 2023  Cu2+ are ubiquitous ions in the ecosystem and ...
# 29   21 June 2023  A thermal-sensitive molecularly imprinted opto...
# 30   22 June 2023  Lipophilic marine biotoxins (LMBs) are one of ...
# 31   13 June 2023  γ-Nonalactone is a linear aliphatic lactone ub...

# %%
#data export #with _demo
if not os.path.exists('data'):
    os.makedirs('data')
    pd.DataFrame(high_papers_df).to_csv('data/high_journal_demo.csv', index = False)
    pd.DataFrame(low_papers_df).to_csv('data/low_journal_demo.csv', index = False)

else:
    try:
        #load & concat
        high_journal_df = pd.read_csv('data/high_journal_demo.csv')
        high_journal_df = pd.concat(high_journal_df, high_papers_df)
        low_journal_df = pd.read_csv('data/low_journal_demo.csv')
        low_journal_df = pd.concat(low_journal_df, low_papers_df)
        #export
        pd.DataFrame(high_journal_df).to_csv('data/high_journal_demo.csv', index = False)
        pd.DataFrame(low_journal_df).to_csv('data/low_journal_demo.csv', index = False)
    except:
        pd.DataFrame(high_papers_df).to_csv('data/high_journal_demo.csv', index = False)
        pd.DataFrame(low_papers_df).to_csv('data/low_journal_demo.csv', index = False)
